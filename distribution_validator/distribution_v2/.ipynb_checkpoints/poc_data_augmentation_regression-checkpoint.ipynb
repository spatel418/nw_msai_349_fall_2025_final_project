# %%
import os
os.chdir("/mnt/c/Users/16303/misc/antonio_molecules/chemetrian/notebooks/chemetrian-data-augmentation-notebooks/mmli/distribution_validator/distribution_v2")
import regression
train_path = "/mnt/c/Users/16303/misc/antonio_molecules/chemetrian/notebooks/chemetrian-data-augmentation-notebooks/mmli/MMLI_train.csv"
test_path = "/mnt/c/Users/16303/misc/antonio_molecules/chemetrian/notebooks/chemetrian-data-augmentation-notebooks/mmli/MMLI_infer.csv"
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
#mmli
df_train = pd.read_csv(train_path)
df_train = df_train.drop(columns=["Batch_ID", "Smiles"])
df_infer = pd.read_csv(test_path)
target = "T80"
print(df_train.columns)
# Out:
# Index(['T80', 'Mass', 'HAcceptors', 'HDonors', 'LogP', 'Asphericity', 'Rg',
#        'TPSA', 'RingCount', 'NumRotatableBonds',
#        ...
#        'SDOS4.5', 'SDOS4.6', 'SDOS4.7', 'SDOS4.8', 'SDOS4.9', 'SDOS5.0',
#        'SDOS5.1', 'SDOS5.2', 'SDOS5.3', 'SDOS5.4'],
#       dtype='object', length=144)

# %%
#train
reg_train = regression.RegressionBuilder(
        df_train,
        None,
        target,
        hyperparameters_tune=True,
        feature_selection_autoselect=True,
        model_choice=["randomforest"],#ast.literal_eval(job_params["models"]),
        goal_metric="mse",
        data_augmentation=True,#job_params["data_augmentation"].lower() == "true",
        feature_selection_num=0,
        saved_model=None,
        saved_scaler=None,
        data_augmentation_method="vae",
        data_augmentation_sectioning="kde",
        data_augmentation_region_num=20,#10,#5,
        data_augmentation_min_samples_per_region=5,#15,#15,
        balance_strategy="increase",
        k=5,
        sampling_method="kfold"
    ).run_regression()
# Out:
# Fold 1 / 5
# X.shape data augment vae - (27, 143)
# Using device: cuda
# Training VAE with 16 latent dimensions
# Epoch 10/200, Loss: 145.097376
# Epoch 20/200, Loss: 143.652027
# Epoch 30/200, Loss: 142.838840
# Epoch 40/200, Loss: 137.395589
# Epoch 50/200, Loss: 133.385842
# Epoch 60/200, Loss: 115.261891
# Epoch 70/200, Loss: 109.717810
# Epoch 80/200, Loss: 103.516014
# Epoch 90/200, Loss: 95.147126
# Epoch 100/200, Loss: 90.514504
# Epoch 110/200, Loss: 84.016412
# Epoch 120/200, Loss: 79.624792
# Epoch 130/200, Loss: 73.646552
# Epoch 140/200, Loss: 71.362205
# Epoch 150/200, Loss: 69.232318
# Epoch 160/200, Loss: 67.656123
# Epoch 170/200, Loss: 65.751840
# Epoch 180/200, Loss: 61.657471
# Epoch 190/200, Loss: 61.314363
# Epoch 200/200, Loss: 62.326005
# Using 5 nearest neighbors for 27 samples
# Finding neighbors in VAE latent space
# Using pre-existing region information from stratified split
# Region distribution before augmentation:
#   Region 1 (1.50 to 1.62): 2 samples → Target: 5
#   Region 2 (1.62 to 2.18): 1 samples → Target: 5
#   Region 3 (2.18 to 2.41): 1 samples → Target: 5
#   Region 4 (2.41 to 3.40): 2 samples → Target: 5
#   Region 5 (3.40 to 5.17): 1 samples → Target: 5
#   Region 6 (5.17 to 6.40): 1 samples → Target: 5
#   Region 7 (6.40 to 7.94): 2 samples → Target: 5
#   Region 8 (7.94 to 8.73): 1 samples → Target: 5
#   Region 9 (8.73 to 9.17): 1 samples → Target: 5
#   Region 10 (9.17 to 10.48): 1 samples → Target: 5
#   Region 11 (10.48 to 10.58): 2 samples → Target: 5
#   Region 12 (10.58 to 10.85): 1 samples → Target: 5
#   Region 13 (10.85 to 14.59): 1 samples → Target: 5
#   Region 14 (14.59 to 20.20): 2 samples → Target: 5
#   Region 15 (20.20 to 24.00): 1 samples → Target: 5
#   Region 16 (24.00 to 35.97): 1 samples → Target: 5
#   Region 17 (35.97 to 47.30): 2 samples → Target: 5
#   Region 18 (47.30 to 69.77): 1 samples → Target: 5
#   Region 19 (69.77 to 92.35): 1 samples → Target: 5
#   Region 20 (92.35 to 103.86): 2 samples → Target: 5
# Initial KDE quality: bandwidth=11.2872, log-likelihood=-4.2883
# Increased bandwidth: 16.9307, log-likelihood: -4.4874
# Decreased bandwidth: 8.4654, log-likelihood: -4.1495
# Selected bandwidth: 8.4654, log-likelihood: -4.1495
# Initial KDE quality: bandwidth=11.2872, log-likelihood=-4.2883
# Increased bandwidth: 16.9307, log-likelihood: -4.4874
# Decreased bandwidth: 8.4654, log-likelihood: -4.1495
# Selected bandwidth: 8.4654, log-likelihood: -4.1495
# Initial KDE quality: bandwidth=11.2872, log-likelihood=-4.2883
# Increased bandwidth: 16.9307, log-likelihood: -4.4874
# Decreased bandwidth: 8.4654, log-likelihood: -4.1495
# Selected bandwidth: 8.4654, log-likelihood: -4.1495
# Generating synthetic samples with KDE-based balanced upsampling...
# Region 1: Generating 3 synthetic samples
# Region 2: Generating 4 synthetic samples
# Region 3: Generating 4 synthetic samples
# Region 4: Generating 3 synthetic samples
# Region 5: Generating 4 synthetic samples
# Region 6: Generating 4 synthetic samples
# Region 7: Generating 3 synthetic samples
# Region 8: Generating 4 synthetic samples
# Region 9: Generating 4 synthetic samples
# Region 10: Generating 4 synthetic samples
# Region 11: Generating 3 synthetic samples
# Region 12: Generating 4 synthetic samples
# Region 13: Generating 4 synthetic samples
# Region 14: Generating 3 synthetic samples
# Region 15: Generating 4 synthetic samples
# Region 16: Generating 4 synthetic samples
# Region 17: Generating 3 synthetic samples
# Region 18: Generating 4 synthetic samples
# Region 19: Generating 4 synthetic samples
# Region 20: Generating 3 synthetic samples
#
# Region distribution after augmentation:
#   Region 1 (1.50 to 1.62): 2 + 0 = 2 samples
#   Region 2 (1.62 to 2.18): 1 + 4 = 5 samples
#   Region 3 (2.18 to 2.41): 1 + 1 = 2 samples
#   Region 4 (2.41 to 3.40): 2 + 3 = 5 samples
#   Region 5 (3.40 to 5.17): 1 + 4 = 5 samples
#   Region 6 (5.17 to 6.40): 1 + 0 = 1 samples
#   Region 7 (6.40 to 7.94): 2 + 7 = 9 samples
#   Region 8 (7.94 to 8.73): 1 + 2 = 3 samples
#   Region 9 (8.73 to 9.17): 1 + 0 = 1 samples
#   Region 10 (9.17 to 10.48): 1 + 9 = 10 samples
#   Region 11 (10.48 to 10.58): 2 + 1 = 3 samples
#   Region 12 (10.58 to 10.85): 1 + 2 = 3 samples
#   Region 13 (10.85 to 14.59): 1 + 7 = 8 samples
#   Region 14 (14.59 to 20.20): 2 + 8 = 10 samples
#   Region 15 (20.20 to 24.00): 1 + 0 = 1 samples
#   Region 16 (24.00 to 35.97): 1 + 10 = 11 samples
#   Region 17 (35.97 to 47.30): 2 + 5 = 7 samples
#   Region 18 (47.30 to 69.77): 1 + 8 = 9 samples
#   Region 19 (69.77 to 92.35): 1 + 2 = 3 samples
#   Region 20 (92.35 to 103.86): 2 + 0 = 2 samples
# Generated 73 synthetic samples in 0.21 seconds
# x synthetic = [[ 6.2935236e+02  6.1194391e+00  3.6085665e-01 ...  4.6408060e-01
#    5.4483038e-01  6.1642200e-01]
#  [ 6.2740814e+02  6.0840044e+00  3.5316858e-01 ...  4.6899888e-01
#    5.5545586e-01  6.2435049e-01]
#  [ 6.1149188e+02  5.8759642e+00  3.4041467e-01 ...  4.5473689e-01
#    5.4233408e-01  6.1174047e-01]
#  ...
#  [ 3.7381567e+02  2.3510036e+00 -4.5137260e-02 ...  3.1582308e-01
#    2.2187348e-01  1.0708368e-01]
#  [ 4.5552090e+02  3.7483664e+00  7.1348220e-02 ...  3.5309294e-01
#    2.9915282e-01  2.6951870e-01]
#  [ 4.4024652e+02  3.3603215e+00  4.8151236e-02 ...  3.5663539e-01
#    2.9997355e-01  2.4115872e-01]]
# 2025-09-09 01:04:35,168 - INFO - Best parameters: {'bootstrap': True, 'max_depth': 16, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 33, 'oob_score': False}
# Fold 2 / 5
# X.shape data augment vae - (27, 143)
# Using device: cuda
# Training VAE with 16 latent dimensions
# Epoch 10/200, Loss: 144.960223
# Epoch 20/200, Loss: 144.342719
# Epoch 30/200, Loss: 143.240840
# Epoch 40/200, Loss: 139.740044
# Epoch 50/200, Loss: 128.573477
# Epoch 60/200, Loss: 119.780436
# Epoch 70/200, Loss: 109.684444
# Epoch 80/200, Loss: 101.322591
# Epoch 90/200, Loss: 96.024875
# Epoch 100/200, Loss: 95.507270
# Epoch 110/200, Loss: 87.897859
# Epoch 120/200, Loss: 84.990741
# Epoch 130/200, Loss: 80.557183
# Epoch 140/200, Loss: 77.015544
# Epoch 150/200, Loss: 72.975455
# Epoch 160/200, Loss: 72.700656
# Epoch 170/200, Loss: 71.433169
# Epoch 180/200, Loss: 70.077632
# Epoch 190/200, Loss: 65.934521
# Epoch 200/200, Loss: 66.345265
# Using 5 nearest neighbors for 27 samples
# Finding neighbors in VAE latent space
# Using pre-existing region information from stratified split
# Region distribution before augmentation:
#   Region 1 (1.50 to 2.38): 2 samples → Target: 5
#   Region 2 (2.38 to 2.77): 1 samples → Target: 5
#   Region 3 (2.77 to 4.62): 1 samples → Target: 5
#   Region 4 (4.62 to 5.33): 2 samples → Target: 5
#   Region 5 (5.33 to 7.77): 1 samples → Target: 5
#   Region 6 (7.77 to 9.09): 1 samples → Target: 5
#   Region 7 (9.09 to 9.42): 2 samples → Target: 5
#   Region 8 (9.42 to 10.53): 1 samples → Target: 5
#   Region 9 (10.53 to 10.74): 1 samples → Target: 5
#   Region 10 (10.74 to 10.88): 1 samples → Target: 5
#   Region 11 (10.88 to 16.34): 2 samples → Target: 5
#   Region 12 (16.34 to 20.25): 1 samples → Target: 5
#   Region 13 (20.25 to 22.86): 1 samples → Target: 5
#   Region 14 (22.86 to 26.32): 2 samples → Target: 5
#   Region 15 (26.32 to 32.05): 1 samples → Target: 5
#   Region 16 (32.05 to 37.43): 1 samples → Target: 5
#   Region 17 (37.43 to 45.26): 2 samples → Target: 5
#   Region 18 (45.26 to 56.15): 1 samples → Target: 5
#   Region 19 (56.15 to 70.83): 1 samples → Target: 5
#   Region 20 (70.83 to 103.86): 2 samples → Target: 5
# Initial KDE quality: bandwidth=9.5607, log-likelihood=-4.2955
# Increased bandwidth: 14.3410, log-likelihood: -4.4326
# Decreased bandwidth: 7.1705, log-likelihood: -4.2007
# Selected bandwidth: 7.1705, log-likelihood: -4.2007
# Initial KDE quality: bandwidth=9.5607, log-likelihood=-4.2955
# Increased bandwidth: 14.3410, log-likelihood: -4.4326
# Decreased bandwidth: 7.1705, log-likelihood: -4.2007
# Selected bandwidth: 7.1705, log-likelihood: -4.2007
# Initial KDE quality: bandwidth=9.5607, log-likelihood=-4.2955
# Increased bandwidth: 14.3410, log-likelihood: -4.4326
# Decreased bandwidth: 7.1705, log-likelihood: -4.2007
# Selected bandwidth: 7.1705, log-likelihood: -4.2007
# Generating synthetic samples with KDE-based balanced upsampling...
# Region 1: Generating 3 synthetic samples
# Region 2: Generating 4 synthetic samples
# Region 3: Generating 4 synthetic samples
# Region 4: Generating 3 synthetic samples
# Region 5: Generating 4 synthetic samples
# Region 6: Generating 4 synthetic samples
# Region 7: Generating 3 synthetic samples
# Region 8: Generating 4 synthetic samples
# Region 9: Generating 4 synthetic samples
# Region 10: Generating 4 synthetic samples
# Region 11: Generating 3 synthetic samples
# Region 12: Generating 4 synthetic samples
# Region 13: Generating 4 synthetic samples
# Region 14: Generating 3 synthetic samples
# Region 15: Generating 4 synthetic samples
# Region 16: Generating 4 synthetic samples
# Region 17: Generating 3 synthetic samples
# Region 18: Generating 4 synthetic samples
# Region 19: Generating 4 synthetic samples
# Region 20: Generating 3 synthetic samples
#
# Region distribution after augmentation:
#   Region 1 (1.50 to 2.38): 2 + 1 = 3 samples
#   Region 2 (2.38 to 2.77): 1 + 1 = 2 samples
#   Region 3 (2.77 to 4.62): 1 + 3 = 4 samples
#   Region 4 (4.62 to 5.33): 2 + 0 = 2 samples
#   Region 5 (5.33 to 7.77): 1 + 7 = 8 samples
#   Region 6 (7.77 to 9.09): 1 + 2 = 3 samples
#   Region 7 (9.09 to 9.42): 2 + 1 = 3 samples
#   Region 8 (9.42 to 10.53): 1 + 8 = 9 samples
#   Region 9 (10.53 to 10.74): 1 + 0 = 1 samples
#   Region 10 (10.74 to 10.88): 1 + 1 = 2 samples
#   Region 11 (10.88 to 16.34): 2 + 6 = 8 samples
#   Region 12 (16.34 to 20.25): 1 + 4 = 5 samples
#   Region 13 (20.25 to 22.86): 1 + 3 = 4 samples
#   Region 14 (22.86 to 26.32): 2 + 2 = 4 samples
#   Region 15 (26.32 to 32.05): 1 + 9 = 10 samples
#   Region 16 (32.05 to 37.43): 1 + 6 = 7 samples
#   Region 17 (37.43 to 45.26): 2 + 5 = 7 samples
#   Region 18 (45.26 to 56.15): 1 + 10 = 11 samples
#   Region 19 (56.15 to 70.83): 1 + 4 = 5 samples
#   Region 20 (70.83 to 103.86): 2 + 0 = 2 samples
# Generated 73 synthetic samples in 0.12 seconds
# x synthetic = [[6.2448004e+02 5.9829917e+00 3.1218034e-01 ... 4.2103320e-01
#   5.5317140e-01 5.5967456e-01]
#  [6.2560101e+02 6.0313945e+00 3.1881037e-01 ... 4.1627055e-01
#   5.4244518e-01 5.6033105e-01]
#  [6.1252509e+02 5.8259301e+00 2.8615588e-01 ... 4.3696448e-01
#   5.7001239e-01 5.8698094e-01]
#  ...
#  [5.4460632e+02 4.8301611e+00 1.3635236e-01 ... 4.6429497e-01
#   5.7724726e-01 6.0496408e-01]
#  [4.3133755e+02 3.8512189e+00 8.5669108e-02 ... 6.4441949e-02
#   2.4776373e-02 5.0645810e-02]
#  [6.8044952e+02 5.1168075e+00 2.5131011e-01 ... 1.0667664e+00
#   1.4057626e+00 1.3586483e+00]]
# 2025-09-09 01:05:36,942 - INFO - Best parameters: {'bootstrap': True, 'max_depth': 16, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 33, 'oob_score': False}
# Fold 3 / 5
# X.shape data augment vae - (27, 143)
# Using device: cuda
# Training VAE with 16 latent dimensions
# Epoch 10/200, Loss: 144.850911
# Epoch 20/200, Loss: 144.210458
# Epoch 30/200, Loss: 143.687382
# Epoch 40/200, Loss: 141.653447
# Epoch 50/200, Loss: 133.500669
# Epoch 60/200, Loss: 121.353968
# Epoch 70/200, Loss: 109.970658
# Epoch 80/200, Loss: 100.031612
# Epoch 90/200, Loss: 92.809932
# Epoch 100/200, Loss: 85.323893
# Epoch 110/200, Loss: 80.801993
# Epoch 120/200, Loss: 76.298611
# Epoch 130/200, Loss: 73.488322
# Epoch 140/200, Loss: 73.026955
# Epoch 150/200, Loss: 68.252853
# Epoch 160/200, Loss: 68.065796
# Epoch 170/200, Loss: 67.206923
# Epoch 180/200, Loss: 64.549108
# Epoch 190/200, Loss: 62.852182
# Epoch 200/200, Loss: 65.137646
# Using 5 nearest neighbors for 27 samples
# Finding neighbors in VAE latent space
# Using pre-existing region information from stratified split
# Region distribution before augmentation:
#   Region 1 (1.50 to 2.04): 2 samples → Target: 5
#   Region 2 (2.04 to 2.40): 1 samples → Target: 5
#   Region 3 (2.40 to 4.56): 1 samples → Target: 5
#   Region 4 (4.56 to 5.07): 2 samples → Target: 5
#   Region 5 (5.07 to 6.60): 1 samples → Target: 5
#   Region 6 (6.60 to 8.48): 1 samples → Target: 5
#   Region 7 (8.48 to 8.90): 2 samples → Target: 5
#   Region 8 (8.90 to 9.21): 1 samples → Target: 5
#   Region 9 (9.21 to 10.13): 1 samples → Target: 5
#   Region 10 (10.13 to 10.49): 1 samples → Target: 5
#   Region 11 (10.49 to 10.66): 2 samples → Target: 5
#   Region 12 (10.66 to 13.32): 1 samples → Target: 5
#   Region 13 (13.32 to 20.18): 1 samples → Target: 5
#   Region 14 (20.18 to 24.86): 2 samples → Target: 5
#   Region 15 (24.86 to 32.05): 1 samples → Target: 5
#   Region 16 (32.05 to 37.43): 1 samples → Target: 5
#   Region 17 (37.43 to 45.26): 2 samples → Target: 5
#   Region 18 (45.26 to 56.15): 1 samples → Target: 5
#   Region 19 (56.15 to 70.83): 1 samples → Target: 5
#   Region 20 (70.83 to 101.13): 2 samples → Target: 5
# Initial KDE quality: bandwidth=9.5865, log-likelihood=-4.2520
# Increased bandwidth: 14.3798, log-likelihood: -4.4169
# Decreased bandwidth: 7.1899, log-likelihood: -4.1318
# Selected bandwidth: 7.1899, log-likelihood: -4.1318
# Initial KDE quality: bandwidth=9.5865, log-likelihood=-4.2520
# Increased bandwidth: 14.3798, log-likelihood: -4.4169
# Decreased bandwidth: 7.1899, log-likelihood: -4.1318
# Selected bandwidth: 7.1899, log-likelihood: -4.1318
# Initial KDE quality: bandwidth=9.5865, log-likelihood=-4.2520
# Increased bandwidth: 14.3798, log-likelihood: -4.4169
# Decreased bandwidth: 7.1899, log-likelihood: -4.1318
# Selected bandwidth: 7.1899, log-likelihood: -4.1318
# Generating synthetic samples with KDE-based balanced upsampling...
# Region 1: Generating 3 synthetic samples
# Region 2: Generating 4 synthetic samples
# Region 3: Generating 4 synthetic samples
# Region 4: Generating 3 synthetic samples
# Region 5: Generating 4 synthetic samples
# Region 6: Generating 4 synthetic samples
# Region 7: Generating 3 synthetic samples
# Region 8: Generating 4 synthetic samples
# Region 9: Generating 4 synthetic samples
# Region 10: Generating 4 synthetic samples
# Region 11: Generating 3 synthetic samples
# Region 12: Generating 4 synthetic samples
# Region 13: Generating 4 synthetic samples
# Region 14: Generating 3 synthetic samples
# Region 15: Generating 4 synthetic samples
# Region 16: Generating 4 synthetic samples
# Region 17: Generating 3 synthetic samples
# Region 18: Generating 4 synthetic samples
# Region 19: Generating 4 synthetic samples
# Region 20: Generating 3 synthetic samples
#
# Region distribution after augmentation:
#   Region 1 (1.50 to 2.04): 2 + 0 = 2 samples
#   Region 2 (2.04 to 2.40): 1 + 0 = 1 samples
#   Region 3 (2.40 to 4.56): 1 + 3 = 4 samples
#   Region 4 (4.56 to 5.07): 2 + 0 = 2 samples
#   Region 5 (5.07 to 6.60): 1 + 8 = 9 samples
#   Region 6 (6.60 to 8.48): 1 + 10 = 11 samples
#   Region 7 (8.48 to 8.90): 2 + 0 = 2 samples
#   Region 8 (8.90 to 9.21): 1 + 3 = 4 samples
#   Region 9 (9.21 to 10.13): 1 + 6 = 7 samples
#   Region 10 (10.13 to 10.49): 1 + 0 = 1 samples
#   Region 11 (10.49 to 10.66): 2 + 1 = 3 samples
#   Region 12 (10.66 to 13.32): 1 + 7 = 8 samples
#   Region 13 (13.32 to 20.18): 1 + 11 = 12 samples
#   Region 14 (20.18 to 24.86): 2 + 4 = 6 samples
#   Region 15 (24.86 to 32.05): 1 + 5 = 6 samples
#   Region 16 (32.05 to 37.43): 1 + 2 = 3 samples
#   Region 17 (37.43 to 45.26): 2 + 1 = 3 samples
#   Region 18 (45.26 to 56.15): 1 + 8 = 9 samples
#   Region 19 (56.15 to 70.83): 1 + 4 = 5 samples
#   Region 20 (70.83 to 101.13): 2 + 0 = 2 samples
# Generated 73 synthetic samples in 0.11 seconds
# x synthetic = [[6.04202698e+02 6.59795904e+00 8.07174444e-02 ... 5.75214684e-01
#   6.22325778e-01 5.75918198e-01]
#  [5.97960693e+02 6.66769695e+00 1.02906436e-01 ... 5.38933694e-01
#   5.78941762e-01 5.40461719e-01]
#  [5.90430237e+02 6.47970581e+00 1.58825725e-01 ... 5.10267615e-01
#   5.71433961e-01 5.35683811e-01]
#  ...
#  [5.20180908e+02 5.01026201e+00 2.32337952e-01 ... 4.15662289e-01
#   3.90218347e-01 4.44738656e-01]
#  [4.19490906e+02 3.19769382e+00 4.19367105e-02 ... 4.30034280e-01
#   4.01043087e-01 3.06646317e-01]
#  [5.96914612e+02 6.03736067e+00 1.00197293e-01 ... 6.06291652e-01
#   6.83672905e-01 6.87849998e-01]]
# 2025-09-09 01:06:42,052 - INFO - Best parameters: {'bootstrap': True, 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 6, 'n_estimators': 32, 'oob_score': True}
# Fold 4 / 5
# X.shape data augment vae - (27, 143)
# Using device: cuda
# Training VAE with 16 latent dimensions
# Epoch 10/200, Loss: 144.934986
# Epoch 20/200, Loss: 144.434778
# Epoch 30/200, Loss: 142.146240
# Epoch 40/200, Loss: 133.785979
# Epoch 50/200, Loss: 125.585205
# Epoch 60/200, Loss: 111.214138
# Epoch 70/200, Loss: 105.233398
# Epoch 80/200, Loss: 94.506013
# Epoch 90/200, Loss: 88.006465
# Epoch 100/200, Loss: 82.124684
# Epoch 110/200, Loss: 74.311754
# Epoch 120/200, Loss: 71.442220
# Epoch 130/200, Loss: 66.035138
# Epoch 140/200, Loss: 66.159202
# Epoch 150/200, Loss: 64.335540
# Epoch 160/200, Loss: 62.979519
# Epoch 170/200, Loss: 62.048136
# Epoch 180/200, Loss: 63.188861
# Epoch 190/200, Loss: 59.925031
# Epoch 200/200, Loss: 59.836462
# Using 5 nearest neighbors for 27 samples
# Finding neighbors in VAE latent space
# Using pre-existing region information from stratified split
# Region distribution before augmentation:
#   Region 1 (1.50 to 1.62): 2 samples → Target: 5
#   Region 2 (1.62 to 2.56): 1 samples → Target: 5
#   Region 3 (2.56 to 4.62): 1 samples → Target: 5
#   Region 4 (4.62 to 5.61): 2 samples → Target: 5
#   Region 5 (5.61 to 7.27): 1 samples → Target: 5
#   Region 6 (7.27 to 8.48): 1 samples → Target: 5
#   Region 7 (8.48 to 8.90): 2 samples → Target: 5
#   Region 8 (8.90 to 9.21): 1 samples → Target: 5
#   Region 9 (9.21 to 10.13): 1 samples → Target: 5
#   Region 10 (10.13 to 10.49): 1 samples → Target: 5
#   Region 11 (10.49 to 10.68): 2 samples → Target: 5
#   Region 12 (10.68 to 16.04): 1 samples → Target: 5
#   Region 13 (16.04 to 20.63): 1 samples → Target: 5
#   Region 14 (20.63 to 23.45): 2 samples → Target: 5
#   Region 15 (23.45 to 28.43): 1 samples → Target: 5
#   Region 16 (28.43 to 32.12): 1 samples → Target: 5
#   Region 17 (32.12 to 39.67): 2 samples → Target: 5
#   Region 18 (39.67 to 57.55): 1 samples → Target: 5
#   Region 19 (57.55 to 92.35): 1 samples → Target: 5
#   Region 20 (92.35 to 103.86): 2 samples → Target: 5
# Initial KDE quality: bandwidth=10.6631, log-likelihood=-4.2714
# Increased bandwidth: 15.9946, log-likelihood: -4.4346
# Decreased bandwidth: 7.9973, log-likelihood: -4.1614
# Selected bandwidth: 7.9973, log-likelihood: -4.1614
# Initial KDE quality: bandwidth=10.6631, log-likelihood=-4.2714
# Increased bandwidth: 15.9946, log-likelihood: -4.4346
# Decreased bandwidth: 7.9973, log-likelihood: -4.1614
# Selected bandwidth: 7.9973, log-likelihood: -4.1614
# Initial KDE quality: bandwidth=10.6631, log-likelihood=-4.2714
# Increased bandwidth: 15.9946, log-likelihood: -4.4346
# Decreased bandwidth: 7.9973, log-likelihood: -4.1614
# Selected bandwidth: 7.9973, log-likelihood: -4.1614
# Generating synthetic samples with KDE-based balanced upsampling...
# Region 1: Generating 3 synthetic samples
# Region 2: Generating 4 synthetic samples
# Region 3: Generating 4 synthetic samples
# Region 4: Generating 3 synthetic samples
# Region 5: Generating 4 synthetic samples
# Region 6: Generating 4 synthetic samples
# Region 7: Generating 3 synthetic samples
# Region 8: Generating 4 synthetic samples
# Region 9: Generating 4 synthetic samples
# Region 10: Generating 4 synthetic samples
# Region 11: Generating 3 synthetic samples
# Region 12: Generating 4 synthetic samples
# Region 13: Generating 4 synthetic samples
# Region 14: Generating 3 synthetic samples
# Region 15: Generating 4 synthetic samples
# Region 16: Generating 4 synthetic samples
# Region 17: Generating 3 synthetic samples
# Region 18: Generating 4 synthetic samples
# Region 19: Generating 4 synthetic samples
# Region 20: Generating 3 synthetic samples
#
# Region distribution after augmentation:
#   Region 1 (1.50 to 1.62): 2 + 0 = 2 samples
#   Region 2 (1.62 to 2.56): 1 + 2 = 3 samples
#   Region 3 (2.56 to 4.62): 1 + 2 = 3 samples
#   Region 4 (4.62 to 5.61): 2 + 0 = 2 samples
#   Region 5 (5.61 to 7.27): 1 + 9 = 10 samples
#   Region 6 (7.27 to 8.48): 1 + 5 = 6 samples
#   Region 7 (8.48 to 8.90): 2 + 1 = 3 samples
#   Region 8 (8.90 to 9.21): 1 + 0 = 1 samples
#   Region 9 (9.21 to 10.13): 1 + 2 = 3 samples
#   Region 10 (10.13 to 10.49): 1 + 1 = 2 samples
#   Region 11 (10.49 to 10.68): 2 + 4 = 6 samples
#   Region 12 (10.68 to 16.04): 1 + 12 = 13 samples
#   Region 13 (16.04 to 20.63): 1 + 8 = 9 samples
#   Region 14 (20.63 to 23.45): 2 + 4 = 6 samples
#   Region 15 (23.45 to 28.43): 1 + 7 = 8 samples
#   Region 16 (28.43 to 32.12): 1 + 3 = 4 samples
#   Region 17 (32.12 to 39.67): 2 + 5 = 7 samples
#   Region 18 (39.67 to 57.55): 1 + 5 = 6 samples
#   Region 19 (57.55 to 92.35): 1 + 3 = 4 samples
#   Region 20 (92.35 to 103.86): 2 + 0 = 2 samples
# Generated 73 synthetic samples in 0.11 seconds
# x synthetic = [[ 6.4873859e+02  6.6262932e+00  3.7169206e-01 ...  5.3224325e-01
#    6.2632304e-01  6.9145900e-01]
#  [ 6.4301263e+02  6.1448951e+00  3.6339545e-01 ...  5.9217471e-01
#    7.4291730e-01  7.6663572e-01]
#  [ 6.3693964e+02  5.8934798e+00  3.5735542e-01 ...  6.2014556e-01
#    7.8860706e-01  8.0040067e-01]
#  ...
#  [ 3.7051276e+02  2.4080396e+00 -3.4048717e-02 ...  2.6216087e-01
#    1.7714907e-01  8.9251883e-02]
#  [ 4.6562891e+02  3.7451546e+00  1.2426620e-01 ...  3.7483823e-01
#    3.4799352e-01  3.1914055e-01]
#  [ 4.1397946e+02  3.0204051e+00  3.4618068e-02 ...  3.1277463e-01
#    2.5903860e-01  1.9138344e-01]]
# 2025-09-09 01:07:43,594 - INFO - Best parameters: {'bootstrap': False, 'max_depth': 14, 'max_features': 'log2', 'min_samples_leaf': 3, 'min_samples_split': 9, 'n_estimators': 122, 'oob_score': False}
# Fold 5 / 5
# X.shape data augment vae - (28, 143)
# Using device: cuda
# Training VAE with 16 latent dimensions
# Epoch 10/200, Loss: 144.287467
# Epoch 20/200, Loss: 143.346401
# Epoch 30/200, Loss: 142.727138
# Epoch 40/200, Loss: 139.704921
# Epoch 50/200, Loss: 131.838475
# Epoch 60/200, Loss: 115.296509
# Epoch 70/200, Loss: 98.752450
# Epoch 80/200, Loss: 91.224845
# Epoch 90/200, Loss: 86.224374
# Epoch 100/200, Loss: 84.126578
# Epoch 110/200, Loss: 82.734506
# Epoch 120/200, Loss: 81.937483
# Epoch 130/200, Loss: 82.886780
# Epoch 140/200, Loss: 76.229876
# Epoch 150/200, Loss: 73.641820
# Epoch 160/200, Loss: 68.486053
# Epoch 170/200, Loss: 69.962128
# Epoch 180/200, Loss: 66.870135
# Epoch 190/200, Loss: 65.052338
# Epoch 200/200, Loss: 61.301052
# Using 5 nearest neighbors for 28 samples
# Finding neighbors in VAE latent space
# Using pre-existing region information from stratified split
# Region distribution before augmentation:
#   Region 1 (1.50 to 1.64): 2 samples → Target: 5
#   Region 2 (1.64 to 2.22): 1 samples → Target: 5
#   Region 3 (2.22 to 2.45): 2 samples → Target: 5
#   Region 4 (2.45 to 3.72): 1 samples → Target: 5
#   Region 5 (3.72 to 4.95): 1 samples → Target: 5
#   Region 6 (4.95 to 5.47): 2 samples → Target: 5
#   Region 7 (5.47 to 7.21): 1 samples → Target: 5
#   Region 8 (7.21 to 8.48): 1 samples → Target: 5
#   Region 9 (8.48 to 9.35): 2 samples → Target: 5
#   Region 10 (9.35 to 10.54): 1 samples → Target: 5
#   Region 11 (10.54 to 10.77): 1 samples → Target: 5
#   Region 12 (10.77 to 11.70): 2 samples → Target: 5
#   Region 13 (11.70 to 17.46): 1 samples → Target: 5
#   Region 14 (17.46 to 20.63): 1 samples → Target: 5
#   Region 15 (20.63 to 26.67): 2 samples → Target: 5
#   Region 16 (26.67 to 32.08): 1 samples → Target: 5
#   Region 17 (32.08 to 44.32): 1 samples → Target: 5
#   Region 18 (44.32 to 54.11): 2 samples → Target: 5
#   Region 19 (54.11 to 89.66): 1 samples → Target: 5
#   Region 20 (89.66 to 103.86): 2 samples → Target: 5
# Initial KDE quality: bandwidth=10.5755, log-likelihood=-4.2583
# Increased bandwidth: 15.8633, log-likelihood: -4.4316
# Decreased bandwidth: 7.9316, log-likelihood: -4.1430
# Selected bandwidth: 7.9316, log-likelihood: -4.1430
# Initial KDE quality: bandwidth=10.5755, log-likelihood=-4.2583
# Increased bandwidth: 15.8633, log-likelihood: -4.4316
# Decreased bandwidth: 7.9316, log-likelihood: -4.1430
# Selected bandwidth: 7.9316, log-likelihood: -4.1430
# Initial KDE quality: bandwidth=10.5755, log-likelihood=-4.2583
# Increased bandwidth: 15.8633, log-likelihood: -4.4316
# Decreased bandwidth: 7.9316, log-likelihood: -4.1430
# Selected bandwidth: 7.9316, log-likelihood: -4.1430
# Generating synthetic samples with KDE-based balanced upsampling...
# Region 1: Generating 3 synthetic samples
# Region 2: Generating 4 synthetic samples
# Region 3: Generating 3 synthetic samples
# Region 4: Generating 4 synthetic samples
# Region 5: Generating 4 synthetic samples
# Region 6: Generating 3 synthetic samples
# Region 7: Generating 4 synthetic samples
# Region 8: Generating 4 synthetic samples
# Region 9: Generating 3 synthetic samples
# Region 10: Generating 4 synthetic samples
# Region 11: Generating 4 synthetic samples
# Region 12: Generating 3 synthetic samples
# Region 13: Generating 4 synthetic samples
# Region 14: Generating 4 synthetic samples
# Region 15: Generating 3 synthetic samples
# Region 16: Generating 4 synthetic samples
# Region 17: Generating 4 synthetic samples
# Region 18: Generating 3 synthetic samples
# Region 19: Generating 4 synthetic samples
# Region 20: Generating 3 synthetic samples
#
# Region distribution after augmentation:
#   Region 1 (1.50 to 1.64): 2 + 0 = 2 samples
#   Region 2 (1.64 to 2.22): 1 + 3 = 4 samples
#   Region 3 (2.22 to 2.45): 2 + 1 = 3 samples
#   Region 4 (2.45 to 3.72): 1 + 2 = 3 samples
#   Region 5 (3.72 to 4.95): 1 + 3 = 4 samples
#   Region 6 (4.95 to 5.47): 2 + 2 = 4 samples
#   Region 7 (5.47 to 7.21): 1 + 4 = 5 samples
#   Region 8 (7.21 to 8.48): 1 + 6 = 7 samples
#   Region 9 (8.48 to 9.35): 2 + 5 = 7 samples
#   Region 10 (9.35 to 10.54): 1 + 7 = 8 samples
#   Region 11 (10.54 to 10.77): 1 + 1 = 2 samples
#   Region 12 (10.77 to 11.70): 2 + 3 = 5 samples
#   Region 13 (11.70 to 17.46): 1 + 10 = 11 samples
#   Region 14 (17.46 to 20.63): 1 + 5 = 6 samples
#   Region 15 (20.63 to 26.67): 2 + 8 = 10 samples
#   Region 16 (26.67 to 32.08): 1 + 1 = 2 samples
#   Region 17 (32.08 to 44.32): 1 + 3 = 4 samples
#   Region 18 (44.32 to 54.11): 2 + 4 = 6 samples
#   Region 19 (54.11 to 89.66): 1 + 4 = 5 samples
#   Region 20 (89.66 to 103.86): 2 + 0 = 2 samples
# Generated 72 synthetic samples in 0.11 seconds
# x synthetic = [[ 6.47873962e+02  6.53870106e+00  4.63499278e-01 ...  5.49398780e-01
#    6.68239594e-01  5.71387410e-01]
#  [ 6.43029236e+02  6.47118855e+00  4.58036840e-01 ...  5.41880310e-01
#    6.55727744e-01  5.54261625e-01]
#  [ 6.22672363e+02  6.05351782e+00  4.22901124e-01 ...  5.18540502e-01
#    6.21187150e-01  5.40202558e-01]
#  ...
#  [ 4.23871887e+02  3.26328993e+00  5.51633462e-02 ...  3.09490025e-01
#    2.66953915e-01  2.45603383e-01]
#  [ 3.66131134e+02  2.32748175e+00 -5.67673519e-02 ...  2.79225856e-01
#    1.96531355e-01  1.58594728e-01]
#  [ 4.45408722e+02  3.69819736e+00  1.22800626e-01 ...  3.06540638e-01
#    2.66444594e-01  2.46291012e-01]]
# 2025-09-09 01:08:46,219 - INFO - Best parameters: {'bootstrap': True, 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 9, 'n_estimators': 58, 'oob_score': True}

# %%
reg_train
# Out:
# {'metrics': {'train_mae': np.float64(7.456174427360305),
#   'train_mse': np.float64(92.12264156554194),
#   'train_adj_r2': 0,
#   'train_r2': 0.891163643199995,
#   'test_mae': np.float64(11.283217514421867),
#   'test_mse': np.float64(224.76239674737033),
#   'test_adj_r2': 0,
#   'test_r2': -0.0710099057976703},
#  'model_name': 'randomforest',
#  'model': RandomForestRegressor(max_depth=16, max_features='sqrt', min_samples_split=5,
#                        n_estimators=33),
#  'hyperparameters': [{'Hyperparameter Name': 'bootstrap',
#    'Hyperparameter Value': True},
#   {'Hyperparameter Name': 'ccp_alpha', 'Hyperparameter Value': 0.0},
#   {'Hyperparameter Name': 'criterion',
#    'Hyperparameter Value': 'squared_error'},
#   {'Hyperparameter Name': 'max_depth', 'Hyperparameter Value': 16},
#   {'Hyperparameter Name': 'max_features', 'Hyperparameter Value': 'sqrt'},
#   {'Hyperparameter Name': 'max_leaf_nodes', 'Hyperparameter Value': None},
#   {'Hyperparameter Name': 'max_samples', 'Hyperparameter Value': None},
#   {'Hyperparameter Name': 'min_impurity_decrease',
#    'Hyperparameter Value': 0.0},
#   {'Hyperparameter Name': 'min_samples_leaf', 'Hyperparameter Value': 1},
#   {'Hyperparameter Name': 'min_samples_split', 'Hyperparameter Value': 5},
#   {'Hyperparameter Name': 'min_weight_fraction_leaf',
#    'Hyperparameter Value': 0.0},
#   {'Hyperparameter Name': 'monotonic_cst', 'Hyperparameter Value': None},
#   {'Hyperparameter Name': 'n_estimators', 'Hyperparameter Value': 33},
#   {'Hyperparameter Name': 'oob_score', 'Hyperparameter Value': False}],
#  'scaler': MinMaxScaler(),
#  'features': ['Mass',
#   'HAcceptors',
#   'HDonors',
#   'Asphericity',
#   'Rg',
#   'NumRotatableBonds',
#   'NumHeteroatoms',
#   'HOMOm1(eV)',
#   'HOMO(eV)',
#   'LUMO(eV)',
#   'LUMOp1(eV)',
#   'PrimeState',
#   'DipoleMoment(Debye)',
#   'T2',
#   'T3',
#   'T5',
#   'T6',
#   'T7',
#   'T11',
#   'T14',
#   'T15',
#   'T19',
#   'S2',
#   'S3',
#   'S4',
#   'S5',
#   'S6',
#   'S7',
#   'S9',
#   'S10',
#   'S11',
#   'S12',
#   'S13',
#   'S14',
#   'S15',
#   'S16',
#   'S17',
#   'S20',
#   'O2',
#   'O3',
#   'O4',
#   'O7',
#   'O9',
#   'O15',
#   'O17',
#   'O18',
#   'O19',
#   'O20',
#   'TDOS1.6',
#   'TDOS1.7',
#   'TDOS1.8',
#   'TDOS1.9',
#   'TDOS2.0',
#   'TDOS2.2',
#   'TDOS2.3',
#   'TDOS2.4',
#   'TDOS2.5',
#   'TDOS2.6',
#   'TDOS2.7',
#   'TDOS2.8',
#   'TDOS3.0',
#   'TDOS3.2',
#   'TDOS3.3',
#   'TDOS3.4',
#   'TDOS3.6',
#   'TDOS3.7',
#   'TDOS3.8',
#   'TDOS3.9',
#   'TDOS4.0',
#   'TDOS4.1',
#   'TDOS4.4',
#   'TDOS4.5',
#   'TDOS4.6',
#   'TDOS4.7',
#   'SDOS2.6',
#   'SDOS2.7',
#   'SDOS2.8',
#   'SDOS2.9',
#   'SDOS3.1',
#   'SDOS3.2',
#   'SDOS3.3',
#   'SDOS3.4',
#   'SDOS3.5',
#   'SDOS3.6',
#   'SDOS4.0',
#   'SDOS4.1',
#   'SDOS4.2',
#   'SDOS4.3',
#   'SDOS4.4',
#   'SDOS4.5',
#   'SDOS4.7',
#   'SDOS4.8',
#   'SDOS4.9',
#   'SDOS5.0',
#   'SDOS5.1'],
#  'goal_metric_per_folds': {'train': [np.float64(92.12264156554194),
#    np.float64(111.64065845420954),
#    np.float64(176.28304592810412),
#    np.float64(103.45043339026985),
#    np.float64(92.9650568721191)],
#   'test': [np.float64(224.76239674737033),
#    np.float64(515.578541440222),
#    np.float64(553.6170547824673),
#    np.float64(620.2896677889959),
#    np.float64(784.7626721050045)]},
#  'true_prediction_point': {'train': [{'true': 103.86,
#     'predicted': 82.31940854406943},
#    {'true': 101.13, 'predicted': 89.37999691673531},
#    {'true': 71.88, 'predicted': 55.706792595295255},
#    {'true': 68.37, 'predicted': 56.8882221885754},
#    {'true': 44.96, 'predicted': 45.85094653216271},
#    {'true': 38.74, 'predicted': 32.3171544146403},
#    {'true': 24.91, 'predicted': 24.479267552945917},
#    {'true': 23.09, 'predicted': 20.306736494436485},
#    {'true': 19.48, 'predicted': 19.637624055117875},
#    {'true': 15.0, 'predicted': 15.229112032110132},
#    {'true': 10.88, 'predicted': 16.52179662953072},
#    {'true': 10.8, 'predicted': 22.11381536948561},
#    {'true': 10.49, 'predicted': 11.723194589918405},
#    {'true': 10.48, 'predicted': 12.543471921961897},
#    {'true': 9.3, 'predicted': 8.436900189412302},
#    {'true': 8.87, 'predicted': 17.51180553516796},
#    {'true': 8.64, 'predicted': 13.318651110729983},
#    {'true': 7.86, 'predicted': 22.616058430952048},
#    {'true': 6.67, 'predicted': 28.181591999219584},
#    {'true': 5.34, 'predicted': 13.836491692569915},
#    {'true': 5.0, 'predicted': 18.244619447063886},
#    {'true': 3.0, 'predicted': 12.197089968002128},
#    {'true': 2.42, 'predicted': 6.105501155560845},
#    {'true': 2.36, 'predicted': 8.265055093877372},
#    {'true': 1.9, 'predicted': 6.6863214821025645},
#    {'true': 1.5, 'predicted': 9.723445173172511},
#    {'true': 1.5, 'predicted': 6.714596216132529}],
#   'test': [{'true': 48.0, 'predicted': 59.754788905793504},
#    {'true': 32.17, 'predicted': 31.768163553721934},
#    {'true': 31.94, 'predicted': 44.08484983792631},
#    {'true': 10.6, 'predicted': 16.54828320387624},
#    {'true': 9.15, 'predicted': 13.97278499615811},
#    {'true': 4.8, 'predicted': 15.248069957873234},
#    {'true': 20.76, 'predicted': 54.22190925304761}]}}

# %%
reg_train
# Out:
# {'metrics': {'train_mae': np.float64(7.456174427360305),
#   'train_mse': np.float64(92.12264156554194),
#   'train_adj_r2': 0,
#   'train_r2': 0.891163643199995,
#   'test_mae': np.float64(11.283217514421867),
#   'test_mse': np.float64(224.76239674737033),
#   'test_adj_r2': 0,
#   'test_r2': -0.0710099057976703},
#  'model_name': 'randomforest',
#  'model': RandomForestRegressor(max_depth=16, max_features='sqrt', min_samples_split=5,
#                        n_estimators=33),
#  'hyperparameters': [{'Hyperparameter Name': 'bootstrap',
#    'Hyperparameter Value': True},
#   {'Hyperparameter Name': 'ccp_alpha', 'Hyperparameter Value': 0.0},
#   {'Hyperparameter Name': 'criterion',
#    'Hyperparameter Value': 'squared_error'},
#   {'Hyperparameter Name': 'max_depth', 'Hyperparameter Value': 16},
#   {'Hyperparameter Name': 'max_features', 'Hyperparameter Value': 'sqrt'},
#   {'Hyperparameter Name': 'max_leaf_nodes', 'Hyperparameter Value': None},
#   {'Hyperparameter Name': 'max_samples', 'Hyperparameter Value': None},
#   {'Hyperparameter Name': 'min_impurity_decrease',
#    'Hyperparameter Value': 0.0},
#   {'Hyperparameter Name': 'min_samples_leaf', 'Hyperparameter Value': 1},
#   {'Hyperparameter Name': 'min_samples_split', 'Hyperparameter Value': 5},
#   {'Hyperparameter Name': 'min_weight_fraction_leaf',
#    'Hyperparameter Value': 0.0},
#   {'Hyperparameter Name': 'monotonic_cst', 'Hyperparameter Value': None},
#   {'Hyperparameter Name': 'n_estimators', 'Hyperparameter Value': 33},
#   {'Hyperparameter Name': 'oob_score', 'Hyperparameter Value': False}],
#  'scaler': MinMaxScaler(),
#  'features': ['Mass',
#   'HAcceptors',
#   'HDonors',
#   'Asphericity',
#   'Rg',
#   'NumRotatableBonds',
#   'NumHeteroatoms',
#   'HOMOm1(eV)',
#   'HOMO(eV)',
#   'LUMO(eV)',
#   'LUMOp1(eV)',
#   'PrimeState',
#   'DipoleMoment(Debye)',
#   'T2',
#   'T3',
#   'T5',
#   'T6',
#   'T7',
#   'T11',
#   'T14',
#   'T15',
#   'T19',
#   'S2',
#   'S3',
#   'S4',
#   'S5',
#   'S6',
#   'S7',
#   'S9',
#   'S10',
#   'S11',
#   'S12',
#   'S13',
#   'S14',
#   'S15',
#   'S16',
#   'S17',
#   'S20',
#   'O2',
#   'O3',
#   'O4',
#   'O7',
#   'O9',
#   'O15',
#   'O17',
#   'O18',
#   'O19',
#   'O20',
#   'TDOS1.6',
#   'TDOS1.7',
#   'TDOS1.8',
#   'TDOS1.9',
#   'TDOS2.0',
#   'TDOS2.2',
#   'TDOS2.3',
#   'TDOS2.4',
#   'TDOS2.5',
#   'TDOS2.6',
#   'TDOS2.7',
#   'TDOS2.8',
#   'TDOS3.0',
#   'TDOS3.2',
#   'TDOS3.3',
#   'TDOS3.4',
#   'TDOS3.6',
#   'TDOS3.7',
#   'TDOS3.8',
#   'TDOS3.9',
#   'TDOS4.0',
#   'TDOS4.1',
#   'TDOS4.4',
#   'TDOS4.5',
#   'TDOS4.6',
#   'TDOS4.7',
#   'SDOS2.6',
#   'SDOS2.7',
#   'SDOS2.8',
#   'SDOS2.9',
#   'SDOS3.1',
#   'SDOS3.2',
#   'SDOS3.3',
#   'SDOS3.4',
#   'SDOS3.5',
#   'SDOS3.6',
#   'SDOS4.0',
#   'SDOS4.1',
#   'SDOS4.2',
#   'SDOS4.3',
#   'SDOS4.4',
#   'SDOS4.5',
#   'SDOS4.7',
#   'SDOS4.8',
#   'SDOS4.9',
#   'SDOS5.0',
#   'SDOS5.1'],
#  'goal_metric_per_folds': {'train': [np.float64(92.12264156554194),
#    np.float64(111.64065845420954),
#    np.float64(176.28304592810412),
#    np.float64(103.45043339026985),
#    np.float64(92.9650568721191)],
#   'test': [np.float64(224.76239674737033),
#    np.float64(515.578541440222),
#    np.float64(553.6170547824673),
#    np.float64(620.2896677889959),
#    np.float64(784.7626721050045)]},
#  'true_prediction_point': {'train': [{'true': 103.86,
#     'predicted': 82.31940854406943},
#    {'true': 101.13, 'predicted': 89.37999691673531},
#    {'true': 71.88, 'predicted': 55.706792595295255},
#    {'true': 68.37, 'predicted': 56.8882221885754},
#    {'true': 44.96, 'predicted': 45.85094653216271},
#    {'true': 38.74, 'predicted': 32.3171544146403},
#    {'true': 24.91, 'predicted': 24.479267552945917},
#    {'true': 23.09, 'predicted': 20.306736494436485},
#    {'true': 19.48, 'predicted': 19.637624055117875},
#    {'true': 15.0, 'predicted': 15.229112032110132},
#    {'true': 10.88, 'predicted': 16.52179662953072},
#    {'true': 10.8, 'predicted': 22.11381536948561},
#    {'true': 10.49, 'predicted': 11.723194589918405},
#    {'true': 10.48, 'predicted': 12.543471921961897},
#    {'true': 9.3, 'predicted': 8.436900189412302},
#    {'true': 8.87, 'predicted': 17.51180553516796},
#    {'true': 8.64, 'predicted': 13.318651110729983},
#    {'true': 7.86, 'predicted': 22.616058430952048},
#    {'true': 6.67, 'predicted': 28.181591999219584},
#    {'true': 5.34, 'predicted': 13.836491692569915},
#    {'true': 5.0, 'predicted': 18.244619447063886},
#    {'true': 3.0, 'predicted': 12.197089968002128},
#    {'true': 2.42, 'predicted': 6.105501155560845},
#    {'true': 2.36, 'predicted': 8.265055093877372},
#    {'true': 1.9, 'predicted': 6.6863214821025645},
#    {'true': 1.5, 'predicted': 9.723445173172511},
#    {'true': 1.5, 'predicted': 6.714596216132529}],
#   'test': [{'true': 48.0, 'predicted': 59.754788905793504},
#    {'true': 32.17, 'predicted': 31.768163553721934},
#    {'true': 31.94, 'predicted': 44.08484983792631},
#    {'true': 10.6, 'predicted': 16.54828320387624},
#    {'true': 9.15, 'predicted': 13.97278499615811},
#    {'true': 4.8, 'predicted': 15.248069957873234},
#    {'true': 20.76, 'predicted': 54.22190925304761}]}}

# %%
target_provided = True
df_infer = df_infer[reg_train["features"] + [target]] if target_provided else df_infer[reg_train["features"]]

# %%
#infer
reg_infer = regression.RegressionBuilder(
        None,
        df_infer,
        target,
        hyperparameters_tune=True,
        feature_selection_autoselect=True,
        model_choice=["randomforest"],#ast.literal_eval(job_params["models"]),
        goal_metric="r2",
        data_augmentation=False,#True,#job_params["data_augmentation"].lower() == "true",
        feature_selection_num=0,
        saved_model=reg_train["model"],
        saved_scaler=reg_train["scaler"],
        data_augmentation_method=None,
        data_augmentation_sectioning=None,
        data_augmentation_region_num=None,
        data_augmentation_min_samples_per_region=None,
        k=5,
        target_provided=target_provided
    ).run_regression()
# Out:
# Index(['Mass', 'HAcceptors', 'HDonors', 'Asphericity', 'Rg',
#        'NumRotatableBonds', 'NumHeteroatoms', 'HOMOm1(eV)', 'HOMO(eV)',
#        'LUMO(eV)', 'LUMOp1(eV)', 'PrimeState', 'DipoleMoment(Debye)', 'T2',
#        'T3', 'T5', 'T6', 'T7', 'T11', 'T14', 'T15', 'T19', 'S2', 'S3', 'S4',
#        'S5', 'S6', 'S7', 'S9', 'S10', 'S11', 'S12', 'S13', 'S14', 'S15', 'S16',
#        'S17', 'S20', 'O2', 'O3', 'O4', 'O7', 'O9', 'O15', 'O17', 'O18', 'O19',
#        'O20', 'TDOS1.6', 'TDOS1.7', 'TDOS1.8', 'TDOS1.9', 'TDOS2.0', 'TDOS2.2',
#        'TDOS2.3', 'TDOS2.4', 'TDOS2.5', 'TDOS2.6', 'TDOS2.7', 'TDOS2.8',
#        'TDOS3.0', 'TDOS3.2', 'TDOS3.3', 'TDOS3.4', 'TDOS3.6', 'TDOS3.7',
#        'TDOS3.8', 'TDOS3.9', 'TDOS4.0', 'TDOS4.1', 'TDOS4.4', 'TDOS4.5',
#        'TDOS4.6', 'TDOS4.7', 'SDOS2.6', 'SDOS2.7', 'SDOS2.8', 'SDOS2.9',
#        'SDOS3.1', 'SDOS3.2', 'SDOS3.3', 'SDOS3.4', 'SDOS3.5', 'SDOS3.6',
#        'SDOS4.0', 'SDOS4.1', 'SDOS4.2', 'SDOS4.3', 'SDOS4.4', 'SDOS4.5',
#        'SDOS4.7', 'SDOS4.8', 'SDOS4.9', 'SDOS5.0', 'SDOS5.1'],
#       dtype='object')

# %%
reg_infer
# Out:
# {'predictions': [62.69072422258212,
#   22.459195662791355,
#   24.673325787260634,
#   12.50384496855334,
#   18.717200719290574,
#   42.019761675859925,
#   30.33461317859833,
#   62.1635106633564],
#  'test_metrics': {'test_mae': np.float64(23.409042138443215),
#   'test_mse': np.float64(837.319030506243),
#   'test_adj_r2': nan,
#   'test_r2': -0.25574814246365984,
#   'test_true_predicted': [{'true': 78.3, 'predicted': 62.69072422258212},
#    {'true': 51.7, 'predicted': 22.459195662791355},
#    {'true': 15.64, 'predicted': 24.673325787260634},
#    {'true': 9.77, 'predicted': 12.50384496855334},
#    {'true': 9.7, 'predicted': 18.717200719290574},
#    {'true': 5.0, 'predicted': 42.019761675859925},
#    {'true': 3.5, 'predicted': 30.33461317859833},
#    {'true': 4.38, 'predicted': 62.1635106633564}]}}

# %%
reg_infer
# Out:
# {'predictions': [62.69072422258212,
#   22.459195662791355,
#   24.673325787260634,
#   12.50384496855334,
#   18.717200719290574,
#   42.019761675859925,
#   30.33461317859833,
#   62.1635106633564],
#  'test_metrics': {'test_mae': np.float64(23.409042138443215),
#   'test_mse': np.float64(837.319030506243),
#   'test_adj_r2': nan,
#   'test_r2': -0.25574814246365984,
#   'test_true_predicted': [{'true': 78.3, 'predicted': 62.69072422258212},
#    {'true': 51.7, 'predicted': 22.459195662791355},
#    {'true': 15.64, 'predicted': 24.673325787260634},
#    {'true': 9.77, 'predicted': 12.50384496855334},
#    {'true': 9.7, 'predicted': 18.717200719290574},
#    {'true': 5.0, 'predicted': 42.019761675859925},
#    {'true': 3.5, 'predicted': 30.33461317859833},
#    {'true': 4.38, 'predicted': 62.1635106633564}]}}

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import glob
import umap
from sklearn.preprocessing import StandardScaler

def analyze_augmentation_quality(base_path, target_col, n_components=2, n_neighbors=15, min_dist=0.1):
    """
    Analyze the quality of data augmentation by comparing distributions.
    
    Args:
        base_path: Path to either 'best_fold' or 'stratified_sampling' directory
        target_col: Name of the target column
        n_components: Number of UMAP dimensions (default: 2)
        n_neighbors: UMAP parameter controlling local vs global structure (default: 15)
        min_dist: UMAP parameter controlling compactness (default: 0.1)
    """
    # Find training file
    if 'best_fold' in base_path:
        train_files = glob.glob(os.path.join(base_path, 'iteration_*_train.csv'))
        if not train_files:
            print(f"No training files found in {base_path}")
            return
        print(f'train files - {train_files}')
        
        train_file = train_files[1] if 'organic' in train_files[0] else train_files[0]  # Use the first iteration file found
    else:
        train_file = os.path.join(base_path, 'train.csv')
        if not os.path.exists(train_file):
            print(f"No training file found at {train_file}")
            return
    
    print(f"Analyzing file: {train_file}")
    
    # Load data
    df = pd.read_csv(train_file)
    
    # Verify required columns exist
    if 'is_organic' not in df.columns:
        print("Error: 'is_organic' column not found in dataset")
        return
    if target_col not in df.columns:
        print(f"Error: Target column '{target_col}' not found in dataset")
        return
    
    # Split data into organic and synthetic
    organic_data = df[df['is_organic'] == True]
    synthetic_data = df[df['is_organic'] == False]
    
    print(f"Dataset contains {len(organic_data)} organic samples and {len(synthetic_data)} synthetic samples")
    
    # STEP 1: Create target distribution histograms
    plt.figure(figsize=(15, 5))
    
    # Histogram 1: Organic data only
    plt.subplot(1, 3, 1)
    plt.hist(organic_data[target_col], bins=30, color='blue', alpha=0.7)
    plt.title('Target Distribution: Organic Data')
    plt.xlabel(target_col)
    plt.ylabel('Frequency')
    
    # Histogram 2: Synthetic data only
    plt.subplot(1, 3, 2)
    plt.hist(synthetic_data[target_col], bins=30, color='red', alpha=0.7)
    plt.title('Target Distribution: Synthetic Data')
    plt.xlabel(target_col)
    plt.ylabel('Frequency')
    
    # Histogram 3: Combined data with different colors
    plt.subplot(1, 3, 3)
    plt.hist([organic_data[target_col], synthetic_data[target_col]], 
             bins=30, color=['blue', 'red'], alpha=0.7,
             label=['Organic', 'Synthetic'])
    plt.title('Target Distribution: Combined Data')
    plt.xlabel(target_col)
    plt.ylabel('Frequency')
    plt.legend()
    
    plt.tight_layout()
    plt.savefig('target_distribution_histograms.png')
    plt.show()
    
    # STEP 2: Create UMAP projections and scatter plots
    # Get all features excluding target and is_organic
    feature_cols = [col for col in df.columns if col != 'is_organic' 
                   and pd.api.types.is_numeric_dtype(df[col])]
    
    if len(feature_cols) < 2:
        print("Error: Not enough numerical features for UMAP")
        return
    
    # Standardize features before UMAP
    X = df[feature_cols]
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)
    
    # Apply UMAP
    reducer = umap.UMAP(n_components=n_components, 
                        n_neighbors=n_neighbors, 
                        min_dist=min_dist,
                        random_state=42)
    
    X_umap = reducer.fit_transform(X_scaled)
    
    # Add UMAP components to dataframe
    umap_cols = [f'UMAP{i+1}' for i in range(n_components)]
    df_umap = pd.DataFrame(X_umap, columns=umap_cols)
    df_umap['is_organic'] = df['is_organic'].values
    df_umap[target_col] = df[target_col].values
    
    # Split the UMAP results by is_organic
    organic_umap = df_umap[df_umap['is_organic'] == True]
    synthetic_umap = df_umap[df_umap['is_organic'] == False]
    
    # Create scatter plots with UMAP dimensions
    plt.figure(figsize=(15, 12))
    
    # 2D Scatter plot of UMAP dimensions
    plt.subplot(2, 2, 1)
    plt.scatter(organic_umap['UMAP1'], organic_umap['UMAP2'], 
                c='blue', alpha=0.5, label='Organic')
    plt.scatter(synthetic_umap['UMAP1'], synthetic_umap['UMAP2'], 
                c='red', alpha=0.5, label='Synthetic')
    plt.xlabel('UMAP1')
    plt.ylabel('UMAP2')
    plt.title('UMAP Projection: Organic vs Synthetic')
    plt.legend()
    
    # Scatter plot of UMAP1 vs target
    plt.subplot(2, 2, 2)
    plt.scatter(organic_umap['UMAP1'], organic_umap[target_col], 
                c='blue', alpha=0.5, label='Organic')
    plt.scatter(synthetic_umap['UMAP1'], synthetic_umap[target_col], 
                c='red', alpha=0.5, label='Synthetic')
    plt.xlabel('UMAP1')
    plt.ylabel(target_col)
    plt.title(f'UMAP1 vs {target_col}')
    plt.legend()
    
    # Scatter plot of UMAP2 vs target
    plt.subplot(2, 2, 3)
    plt.scatter(organic_umap['UMAP2'], organic_umap[target_col], 
                c='blue', alpha=0.5, label='Organic')
    plt.scatter(synthetic_umap['UMAP2'], synthetic_umap[target_col], 
                c='red', alpha=0.5, label='Synthetic')
    plt.xlabel('UMAP2')
    plt.ylabel(target_col)
    plt.title(f'UMAP2 vs {target_col}')
    plt.legend()
    
    # If we have 3 or more components, show UMAP3 vs target
    if n_components >= 3:
        plt.subplot(2, 2, 4)
        plt.scatter(organic_umap['UMAP3'], organic_umap[target_col], 
                    c='blue', alpha=0.5, label='Organic')
        plt.scatter(synthetic_umap['UMAP3'], synthetic_umap[target_col], 
                    c='red', alpha=0.5, label='Synthetic')
        plt.xlabel('UMAP3')
        plt.ylabel(target_col)
        plt.title(f'UMAP3 vs {target_col}')
        plt.legend()
    else:
        # If only 2 components, show density plot of target
        plt.subplot(2, 2, 4)
        sns.kdeplot(organic_umap[target_col], color='blue', label='Organic', fill=True, alpha=0.3)
        sns.kdeplot(synthetic_umap[target_col], color='red', label='Synthetic', fill=True, alpha=0.3)
        plt.xlabel(target_col)
        plt.ylabel('Density')
        plt.title(f'Distribution of {target_col}')
        plt.legend()
    
    plt.tight_layout()
    plt.savefig('umap_visualizations.png')
    plt.show()
    
    # Create 3D scatter plot if we have 3 or more components
    if n_components >= 3:
        fig = plt.figure(figsize=(10, 8))
        ax = fig.add_subplot(111, projection='3d')
        
        ax.scatter(organic_umap['UMAP1'], organic_umap['UMAP2'], organic_umap['UMAP3'], 
                   c='blue', alpha=0.5, label='Organic')
        ax.scatter(synthetic_umap['UMAP1'], synthetic_umap['UMAP2'], synthetic_umap['UMAP3'], 
                   c='red', alpha=0.5, label='Synthetic')
        
        ax.set_xlabel('UMAP1')
        ax.set_ylabel('UMAP2')
        ax.set_zlabel('UMAP3')
        ax.set_title('3D UMAP Projection')
        plt.legend()
        
        plt.tight_layout()
        plt.savefig('umap_3d.png')
        plt.show()
    
    # Additional visualization: Color by target value
    plt.figure(figsize=(15, 6))
    
    # UMAP plot colored by target (organic)
    plt.subplot(1, 2, 1)
    scatter1 = plt.scatter(organic_umap['UMAP1'], organic_umap['UMAP2'], 
                           c=organic_umap[target_col], cmap='viridis', alpha=0.7)
    plt.colorbar(scatter1, label=target_col)
    plt.xlabel('UMAP1')
    plt.ylabel('UMAP2')
    plt.title(f'Organic Data: UMAP colored by {target_col}')
    
    # UMAP plot colored by target (synthetic)
    plt.subplot(1, 2, 2)
    scatter2 = plt.scatter(synthetic_umap['UMAP1'], synthetic_umap['UMAP2'], 
                           c=synthetic_umap[target_col], cmap='viridis', alpha=0.7)
    plt.colorbar(scatter2, label=target_col)
    plt.xlabel('UMAP1')
    plt.ylabel('UMAP2')
    plt.title(f'Synthetic Data: UMAP colored by {target_col}')
    
    plt.tight_layout()
    plt.savefig('umap_target_colored.png')
    plt.show()

# %%
    base_path = "best_fold"  # or "stratified_sampling"
    target_column = target  # replace with your actual target column name
    
    # UMAP parameters
    n_components = 2  # Set to 2 for 2D plots only, 3 for 3D visualization
    n_neighbors = 15  # Lower for local structure, higher for global
    min_dist = 0.1    # Lower for tighter clusters
    
    analyze_augmentation_quality(base_path, target_column, n_components, n_neighbors, min_dist)
# Out:
# train files - ['best_fold/iteration_1_organic_train.csv', 'best_fold/iteration_1_train.csv']
# Analyzing file: best_fold/iteration_1_train.csv
# Dataset contains 27 organic samples and 73 synthetic samples
