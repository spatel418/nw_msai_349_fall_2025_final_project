# %%
import os
os.chdir("/mnt/c/Users/16303/misc/antonio_molecules/chemetrian/notebooks/chemetrian-data-augmentation-notebooks/mmli/random_forest/augmentation/5_fold/vae_kde")
import regression
train_path = "/mnt/c/Users/16303/misc/antonio_molecules/chemetrian/notebooks/chemetrian-data-augmentation-notebooks/mmli/MMLI_train.csv"
test_path = "/mnt/c/Users/16303/misc/antonio_molecules/chemetrian/notebooks/chemetrian-data-augmentation-notebooks/mmli/MMLI_infer.csv"
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
#mmli
df_train = pd.read_csv(train_path)
df_train = df_train.drop(columns=["Batch_ID", "Smiles"])
df_infer = pd.read_csv(test_path)
target = "T80"
print(df_train.columns)
# Out:
# Index(['T80', 'Mass', 'HAcceptors', 'HDonors', 'LogP', 'Asphericity', 'Rg',
#        'TPSA', 'RingCount', 'NumRotatableBonds',
#        ...
#        'SDOS4.5', 'SDOS4.6', 'SDOS4.7', 'SDOS4.8', 'SDOS4.9', 'SDOS5.0',
#        'SDOS5.1', 'SDOS5.2', 'SDOS5.3', 'SDOS5.4'],
#       dtype='object', length=144)

# %%
#train
reg_train = regression.RegressionBuilder(
        df_train,
        None,
        target,
        hyperparameters_tune=True,
        feature_selection_autoselect=True,
        model_choice=["randomforest"],#ast.literal_eval(job_params["models"]),
        goal_metric="mse",
        data_augmentation=True,#job_params["data_augmentation"].lower() == "true",
        feature_selection_num=0,
        saved_model=None,
        saved_scaler=None,
        data_augmentation_method="vae",
        data_augmentation_sectioning="kde",
        data_augmentation_region_num=10,#5,
        data_augmentation_min_samples_per_region=15,#15,
        balance_strategy="increase",
        k=5,
        sampling_method="kfold"
    ).run_regression()
# Out:
# Fold 1 / 5
# X.shape data augment vae - (27, 143)
# Using device: cpu
# Training VAE with 16 latent dimensions
# Epoch 10/200, Loss: 145.777714
# Epoch 20/200, Loss: 144.402244
# Epoch 30/200, Loss: 143.851472
# Epoch 40/200, Loss: 143.242811
# Epoch 50/200, Loss: 139.359447
# Epoch 60/200, Loss: 128.721725
# Epoch 70/200, Loss: 115.670347
# Epoch 80/200, Loss: 104.500036
# Epoch 90/200, Loss: 95.514983
# Epoch 100/200, Loss: 90.523040
# Epoch 110/200, Loss: 81.714120
# Epoch 120/200, Loss: 74.912164
# Epoch 130/200, Loss: 72.467846
# Epoch 140/200, Loss: 70.554959
# Epoch 150/200, Loss: 70.182780
# Epoch 160/200, Loss: 65.595730
# Epoch 170/200, Loss: 64.903528
# Epoch 180/200, Loss: 60.985514
# Epoch 190/200, Loss: 60.032841
# Epoch 200/200, Loss: 65.740298
# Using 5 nearest neighbors for 27 samples
# Finding neighbors in VAE latent space
# Using pre-existing region information from stratified split
# Region distribution before augmentation:
#   Region 1 (1.50 to 2.18): 3 samples → Target: 15
#   Region 2 (2.18 to 3.40): 3 samples → Target: 15
#   Region 3 (3.40 to 6.40): 2 samples → Target: 15
#   Region 4 (6.40 to 8.73): 3 samples → Target: 15
#   Region 5 (8.73 to 10.48): 2 samples → Target: 15
#   Region 6 (10.48 to 10.85): 3 samples → Target: 15
#   Region 7 (10.85 to 20.20): 3 samples → Target: 15
#   Region 8 (20.20 to 35.97): 2 samples → Target: 15
#   Region 9 (35.97 to 69.77): 3 samples → Target: 15
#   Region 10 (69.77 to 103.86): 3 samples → Target: 15
# Initial KDE quality: bandwidth=11.2872, log-likelihood=-4.2883
# Increased bandwidth: 16.9307, log-likelihood: -4.4874
# Decreased bandwidth: 8.4654, log-likelihood: -4.1495
# Selected bandwidth: 8.4654, log-likelihood: -4.1495
# Initial KDE quality: bandwidth=11.2872, log-likelihood=-4.2883
# Increased bandwidth: 16.9307, log-likelihood: -4.4874
# Decreased bandwidth: 8.4654, log-likelihood: -4.1495
# Selected bandwidth: 8.4654, log-likelihood: -4.1495
# Initial KDE quality: bandwidth=11.2872, log-likelihood=-4.2883
# Increased bandwidth: 16.9307, log-likelihood: -4.4874
# Decreased bandwidth: 8.4654, log-likelihood: -4.1495
# Selected bandwidth: 8.4654, log-likelihood: -4.1495
# Generating synthetic samples with KDE-based balanced upsampling...
# Region 1: Generating 12 synthetic samples
# Region 2: Generating 12 synthetic samples
# Region 3: Generating 13 synthetic samples
# Region 4: Generating 12 synthetic samples
# Region 5: Generating 13 synthetic samples
# Region 6: Generating 12 synthetic samples
# Region 7: Generating 12 synthetic samples
# Region 8: Generating 13 synthetic samples
# Region 9: Generating 12 synthetic samples
# Region 10: Generating 12 synthetic samples
#
# Region distribution after augmentation:
#   Region 1 (1.50 to 2.18): 3 + 6 = 9 samples
#   Region 2 (2.18 to 3.40): 3 + 5 = 8 samples
#   Region 3 (3.40 to 6.40): 2 + 12 = 14 samples
#   Region 4 (6.40 to 8.73): 3 + 19 = 22 samples
#   Region 5 (8.73 to 10.48): 2 + 5 = 7 samples
#   Region 6 (10.48 to 10.85): 3 + 4 = 7 samples
#   Region 7 (10.85 to 20.20): 3 + 30 = 33 samples
#   Region 8 (20.20 to 35.97): 2 + 23 = 25 samples
#   Region 9 (35.97 to 69.77): 3 + 17 = 20 samples
#   Region 10 (69.77 to 103.86): 3 + 2 = 5 samples
# Generated 123 synthetic samples in 0.13 seconds
# x synthetic = [[7.3515314e+02 7.5961971e+00 3.5511005e-01 ... 6.9736606e-01
#   8.0537677e-01 8.7272370e-01]
#  [7.2717810e+02 7.9602151e+00 4.1331229e-01 ... 5.8694249e-01
#   6.4713508e-01 7.0015585e-01]
#  [6.9972211e+02 7.4906373e+00 3.9508843e-01 ... 5.4173672e-01
#   6.0747969e-01 6.7082208e-01]
#  ...
#  [4.6033643e+02 3.5680878e+00 5.4196682e-02 ... 3.8818160e-01
#   3.4473661e-01 2.9887280e-01]
#  [6.7696838e+02 5.1263862e+00 2.8013685e-01 ... 8.4661585e-01
#   1.1518157e+00 1.1294787e+00]
#  [5.2503595e+02 4.8490729e+00 2.0806667e-01 ... 3.8958213e-01
#   3.5469067e-01 4.2944679e-01]]
# 2025-09-04 17:54:58,478 - INFO - Best parameters: {'bootstrap': False, 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 6, 'n_estimators': 39, 'oob_score': False}
# Fold 2 / 5
# X.shape data augment vae - (27, 143)
# Using device: cpu
# Training VAE with 16 latent dimensions
# Epoch 10/200, Loss: 144.997143
# Epoch 20/200, Loss: 144.237187
# Epoch 30/200, Loss: 142.879494
# Epoch 40/200, Loss: 138.613860
# Epoch 50/200, Loss: 128.749042
# Epoch 60/200, Loss: 118.539099
# Epoch 70/200, Loss: 109.180112
# Epoch 80/200, Loss: 101.753038
# Epoch 90/200, Loss: 95.925365
# Epoch 100/200, Loss: 92.880037
# Epoch 110/200, Loss: 89.141945
# Epoch 120/200, Loss: 84.385236
# Epoch 130/200, Loss: 80.960938
# Epoch 140/200, Loss: 84.484285
# Epoch 150/200, Loss: 75.407977
# Epoch 160/200, Loss: 73.977883
# Epoch 170/200, Loss: 70.831982
# Epoch 180/200, Loss: 70.696922
# Epoch 190/200, Loss: 67.045180
# Epoch 200/200, Loss: 66.180235
# Using 5 nearest neighbors for 27 samples
# Finding neighbors in VAE latent space
# Using pre-existing region information from stratified split
# Region distribution before augmentation:
#   Region 1 (1.50 to 2.77): 3 samples → Target: 15
#   Region 2 (2.77 to 5.33): 3 samples → Target: 15
#   Region 3 (5.33 to 9.09): 2 samples → Target: 15
#   Region 4 (9.09 to 10.53): 3 samples → Target: 15
#   Region 5 (10.53 to 10.88): 2 samples → Target: 15
#   Region 6 (10.88 to 20.25): 3 samples → Target: 15
#   Region 7 (20.25 to 26.32): 3 samples → Target: 15
#   Region 8 (26.32 to 37.43): 2 samples → Target: 15
#   Region 9 (37.43 to 56.15): 3 samples → Target: 15
#   Region 10 (56.15 to 103.86): 3 samples → Target: 15
# Initial KDE quality: bandwidth=9.5607, log-likelihood=-4.2955
# Increased bandwidth: 14.3410, log-likelihood: -4.4326
# Decreased bandwidth: 7.1705, log-likelihood: -4.2007
# Selected bandwidth: 7.1705, log-likelihood: -4.2007
# Initial KDE quality: bandwidth=9.5607, log-likelihood=-4.2955
# Increased bandwidth: 14.3410, log-likelihood: -4.4326
# Decreased bandwidth: 7.1705, log-likelihood: -4.2007
# Selected bandwidth: 7.1705, log-likelihood: -4.2007
# Initial KDE quality: bandwidth=9.5607, log-likelihood=-4.2955
# Increased bandwidth: 14.3410, log-likelihood: -4.4326
# Decreased bandwidth: 7.1705, log-likelihood: -4.2007
# Selected bandwidth: 7.1705, log-likelihood: -4.2007
# Generating synthetic samples with KDE-based balanced upsampling...
# Region 1: Generating 12 synthetic samples
# Region 2: Generating 12 synthetic samples
# Region 3: Generating 13 synthetic samples
# Region 4: Generating 12 synthetic samples
# Region 5: Generating 13 synthetic samples
# Region 6: Generating 12 synthetic samples
# Region 7: Generating 12 synthetic samples
# Region 8: Generating 13 synthetic samples
# Region 9: Generating 12 synthetic samples
# Region 10: Generating 12 synthetic samples
#
# Region distribution after augmentation:
#   Region 1 (1.50 to 2.77): 3 + 8 = 11 samples
#   Region 2 (2.77 to 5.33): 3 + 7 = 10 samples
#   Region 3 (5.33 to 9.09): 2 + 12 = 14 samples
#   Region 4 (9.09 to 10.53): 3 + 10 = 13 samples
#   Region 5 (10.53 to 10.88): 2 + 3 = 5 samples
#   Region 6 (10.88 to 20.25): 3 + 27 = 30 samples
#   Region 7 (20.25 to 26.32): 3 + 15 = 18 samples
#   Region 8 (26.32 to 37.43): 2 + 20 = 22 samples
#   Region 9 (37.43 to 56.15): 3 + 19 = 22 samples
#   Region 10 (56.15 to 103.86): 3 + 2 = 5 samples
# Generated 123 synthetic samples in 0.07 seconds
# x synthetic = [[6.5342755e+02 5.4759798e+00 2.8540722e-01 ... 7.7375388e-01
#   1.0650326e+00 1.0536990e+00]
#  [6.4974756e+02 5.4123077e+00 2.7705035e-01 ... 7.8145832e-01
#   1.0814780e+00 1.0645704e+00]
#  [6.5512201e+02 5.6915474e+00 2.9824716e-01 ... 7.0327890e-01
#   9.3841928e-01 9.5156908e-01]
#  ...
#  [6.6619867e+02 5.2453313e+00 2.8462851e-01 ... 1.0177923e+00
#   1.3359042e+00 1.3469342e+00]
#  [6.6600098e+02 5.2705650e+00 2.7896392e-01 ... 9.9876904e-01
#   1.3285562e+00 1.3294798e+00]
#  [5.9643036e+02 5.2682810e+00 1.9983359e-01 ... 5.4691315e-01
#   6.5894538e-01 6.8501288e-01]]
# 2025-09-04 17:56:30,731 - INFO - Best parameters: {'bootstrap': False, 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 6, 'n_estimators': 138, 'oob_score': False}
# Fold 3 / 5
# X.shape data augment vae - (27, 143)
# Using device: cpu
# Training VAE with 16 latent dimensions
# Epoch 10/200, Loss: 145.459156
# Epoch 20/200, Loss: 144.382351
# Epoch 30/200, Loss: 143.618707
# Epoch 40/200, Loss: 141.274541
# Epoch 50/200, Loss: 133.689706
# Epoch 60/200, Loss: 124.308738
# Epoch 70/200, Loss: 111.716309
# Epoch 80/200, Loss: 101.791386
# Epoch 90/200, Loss: 94.343714
# Epoch 100/200, Loss: 87.270490
# Epoch 110/200, Loss: 81.550230
# Epoch 120/200, Loss: 76.848723
# Epoch 130/200, Loss: 74.498680
# Epoch 140/200, Loss: 75.152855
# Epoch 150/200, Loss: 70.574124
# Epoch 160/200, Loss: 69.526304
# Epoch 170/200, Loss: 66.238132
# Epoch 180/200, Loss: 67.007392
# Epoch 190/200, Loss: 62.867400
# Epoch 200/200, Loss: 63.211299
# Using 5 nearest neighbors for 27 samples
# Finding neighbors in VAE latent space
# Using pre-existing region information from stratified split
# Region distribution before augmentation:
#   Region 1 (1.50 to 2.40): 3 samples → Target: 15
#   Region 2 (2.40 to 5.07): 3 samples → Target: 15
#   Region 3 (5.07 to 8.48): 2 samples → Target: 15
#   Region 4 (8.48 to 9.21): 3 samples → Target: 15
#   Region 5 (9.21 to 10.49): 2 samples → Target: 15
#   Region 6 (10.49 to 13.32): 3 samples → Target: 15
#   Region 7 (13.32 to 24.86): 3 samples → Target: 15
#   Region 8 (24.86 to 37.43): 2 samples → Target: 15
#   Region 9 (37.43 to 56.15): 3 samples → Target: 15
#   Region 10 (56.15 to 101.13): 3 samples → Target: 15
# Initial KDE quality: bandwidth=9.5865, log-likelihood=-4.2520
# Increased bandwidth: 14.3798, log-likelihood: -4.4169
# Decreased bandwidth: 7.1899, log-likelihood: -4.1318
# Selected bandwidth: 7.1899, log-likelihood: -4.1318
# Initial KDE quality: bandwidth=9.5865, log-likelihood=-4.2520
# Increased bandwidth: 14.3798, log-likelihood: -4.4169
# Decreased bandwidth: 7.1899, log-likelihood: -4.1318
# Selected bandwidth: 7.1899, log-likelihood: -4.1318
# Initial KDE quality: bandwidth=9.5865, log-likelihood=-4.2520
# Increased bandwidth: 14.3798, log-likelihood: -4.4169
# Decreased bandwidth: 7.1899, log-likelihood: -4.1318
# Selected bandwidth: 7.1899, log-likelihood: -4.1318
# Generating synthetic samples with KDE-based balanced upsampling...
# Region 1: Generating 12 synthetic samples
# Region 2: Generating 12 synthetic samples
# Region 3: Generating 13 synthetic samples
# Region 4: Generating 12 synthetic samples
# Region 5: Generating 13 synthetic samples
# Region 6: Generating 12 synthetic samples
# Region 7: Generating 12 synthetic samples
# Region 8: Generating 13 synthetic samples
# Region 9: Generating 12 synthetic samples
# Region 10: Generating 12 synthetic samples
#
# Region distribution after augmentation:
#   Region 1 (1.50 to 2.40): 3 + 2 = 5 samples
#   Region 2 (2.40 to 5.07): 3 + 6 = 9 samples
#   Region 3 (5.07 to 8.48): 2 + 25 = 27 samples
#   Region 4 (8.48 to 9.21): 3 + 5 = 8 samples
#   Region 5 (9.21 to 10.49): 2 + 8 = 10 samples
#   Region 6 (10.49 to 13.32): 3 + 6 = 9 samples
#   Region 7 (13.32 to 24.86): 3 + 27 = 30 samples
#   Region 8 (24.86 to 37.43): 2 + 27 = 29 samples
#   Region 9 (37.43 to 56.15): 3 + 15 = 18 samples
#   Region 10 (56.15 to 101.13): 3 + 2 = 5 samples
# Generated 123 synthetic samples in 0.08 seconds
# x synthetic = [[5.9539728e+02 5.3850703e+00 2.3046800e-01 ... 6.1791337e-01
#   7.8385633e-01 8.3252895e-01]
#  [5.9058820e+02 5.6841764e+00 2.0018388e-01 ... 5.7732183e-01
#   6.7195123e-01 7.2436249e-01]
#  [5.8980566e+02 5.8044586e+00 1.8575016e-01 ... 5.6480867e-01
#   6.4144123e-01 7.0270574e-01]
#  ...
#  [5.9895166e+02 6.4259405e+00 3.7985130e-03 ... 6.6829151e-01
#   6.6518277e-01 6.5885180e-01]
#  [6.0048810e+02 6.3416386e+00 3.8336201e-03 ... 6.9227695e-01
#   7.1303225e-01 6.9315583e-01]
#  [5.2841437e+02 5.5129089e+00 2.8521034e-01 ... 3.2173055e-01
#   2.6668516e-01 3.0127543e-01]]
# 2025-09-04 17:58:04,418 - INFO - Best parameters: {'bootstrap': True, 'max_depth': 16, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 33, 'oob_score': False}
# Fold 4 / 5
# X.shape data augment vae - (27, 143)
# Using device: cpu
# Training VAE with 16 latent dimensions
# Epoch 10/200, Loss: 145.445611
# Epoch 20/200, Loss: 144.366799
# Epoch 30/200, Loss: 144.079518
# Epoch 40/200, Loss: 142.484565
# Epoch 50/200, Loss: 135.349510
# Epoch 60/200, Loss: 125.112874
# Epoch 70/200, Loss: 104.839455
# Epoch 80/200, Loss: 91.280382
# Epoch 90/200, Loss: 81.208876
# Epoch 100/200, Loss: 73.471124
# Epoch 110/200, Loss: 69.264214
# Epoch 120/200, Loss: 69.407204
# Epoch 130/200, Loss: 65.828903
# Epoch 140/200, Loss: 71.441917
# Epoch 150/200, Loss: 62.588854
# Epoch 160/200, Loss: 61.261669
# Epoch 170/200, Loss: 59.914560
# Epoch 180/200, Loss: 60.803611
# Epoch 190/200, Loss: 57.465106
# Epoch 200/200, Loss: 60.814553
# Using 5 nearest neighbors for 27 samples
# Finding neighbors in VAE latent space
# Using pre-existing region information from stratified split
# Region distribution before augmentation:
#   Region 1 (1.50 to 2.56): 3 samples → Target: 15
#   Region 2 (2.56 to 5.61): 3 samples → Target: 15
#   Region 3 (5.61 to 8.48): 2 samples → Target: 15
#   Region 4 (8.48 to 9.21): 3 samples → Target: 15
#   Region 5 (9.21 to 10.49): 2 samples → Target: 15
#   Region 6 (10.49 to 16.04): 3 samples → Target: 15
#   Region 7 (16.04 to 23.45): 3 samples → Target: 15
#   Region 8 (23.45 to 32.12): 2 samples → Target: 15
#   Region 9 (32.12 to 57.55): 3 samples → Target: 15
#   Region 10 (57.55 to 103.86): 3 samples → Target: 15
# Initial KDE quality: bandwidth=10.6631, log-likelihood=-4.2714
# Increased bandwidth: 15.9946, log-likelihood: -4.4346
# Decreased bandwidth: 7.9973, log-likelihood: -4.1614
# Selected bandwidth: 7.9973, log-likelihood: -4.1614
# Initial KDE quality: bandwidth=10.6631, log-likelihood=-4.2714
# Increased bandwidth: 15.9946, log-likelihood: -4.4346
# Decreased bandwidth: 7.9973, log-likelihood: -4.1614
# Selected bandwidth: 7.9973, log-likelihood: -4.1614
# Initial KDE quality: bandwidth=10.6631, log-likelihood=-4.2714
# Increased bandwidth: 15.9946, log-likelihood: -4.4346
# Decreased bandwidth: 7.9973, log-likelihood: -4.1614
# Selected bandwidth: 7.9973, log-likelihood: -4.1614
# Generating synthetic samples with KDE-based balanced upsampling...
# Region 1: Generating 12 synthetic samples
# Region 2: Generating 12 synthetic samples
# Region 3: Generating 13 synthetic samples
# Region 4: Generating 12 synthetic samples
# Region 5: Generating 13 synthetic samples
# Region 6: Generating 12 synthetic samples
# Region 7: Generating 12 synthetic samples
# Region 8: Generating 13 synthetic samples
# Region 9: Generating 12 synthetic samples
# Region 10: Generating 12 synthetic samples
#
# Region distribution after augmentation:
#   Region 1 (1.50 to 2.56): 3 + 3 = 6 samples
#   Region 2 (2.56 to 5.61): 3 + 5 = 8 samples
#   Region 3 (5.61 to 8.48): 2 + 24 = 26 samples
#   Region 4 (8.48 to 9.21): 3 + 1 = 4 samples
#   Region 5 (9.21 to 10.49): 2 + 11 = 13 samples
#   Region 6 (10.49 to 16.04): 3 + 21 = 24 samples
#   Region 7 (16.04 to 23.45): 3 + 28 = 31 samples
#   Region 8 (23.45 to 32.12): 2 + 10 = 12 samples
#   Region 9 (32.12 to 57.55): 3 + 16 = 19 samples
#   Region 10 (57.55 to 103.86): 3 + 4 = 7 samples
# Generated 123 synthetic samples in 0.07 seconds
# x synthetic = [[7.3295691e+02 8.0184994e+00 4.3291512e-01 ... 8.1596196e-01
#   9.6108955e-01 9.5249850e-01]
#  [7.0565631e+02 7.9016371e+00 3.7605360e-01 ... 6.6687340e-01
#   7.7120370e-01 8.0731744e-01]
#  [6.9153619e+02 7.4309716e+00 3.7161642e-01 ... 6.7549205e-01
#   8.0559301e-01 8.2733852e-01]
#  ...
#  [4.2493091e+02 3.2014143e+00 3.3391047e-02 ... 4.1857857e-01
#   3.6425203e-01 3.0187863e-01]
#  [6.9904456e+02 6.6405144e+00 4.4673476e-01 ... 8.9820659e-01
#   1.1190945e+00 1.0353867e+00]
#  [5.6531927e+02 5.1422920e+00 2.8945291e-01 ... 4.0048510e-01
#   4.8221892e-01 4.3520477e-01]]
# 2025-09-04 17:59:42,622 - INFO - Best parameters: {'bootstrap': False, 'max_depth': 18, 'max_features': 'log2', 'min_samples_leaf': 6, 'min_samples_split': 6, 'n_estimators': 75, 'oob_score': False}
# Fold 5 / 5
# X.shape data augment vae - (28, 143)
# Using device: cpu
# Training VAE with 16 latent dimensions
# Epoch 10/200, Loss: 144.733067
# Epoch 20/200, Loss: 143.791896
# Epoch 30/200, Loss: 142.340166
# Epoch 40/200, Loss: 141.229510
# Epoch 50/200, Loss: 129.579817
# Epoch 60/200, Loss: 113.645700
# Epoch 70/200, Loss: 97.713091
# Epoch 80/200, Loss: 89.872489
# Epoch 90/200, Loss: 85.206761
# Epoch 100/200, Loss: 84.722883
# Epoch 110/200, Loss: 85.277318
# Epoch 120/200, Loss: 82.417027
# Epoch 130/200, Loss: 79.622995
# Epoch 140/200, Loss: 79.639082
# Epoch 150/200, Loss: 75.515294
# Epoch 160/200, Loss: 72.097111
# Epoch 170/200, Loss: 70.711278
# Epoch 180/200, Loss: 65.942910
# Epoch 190/200, Loss: 65.986546
# Epoch 200/200, Loss: 64.179910
# Using 5 nearest neighbors for 28 samples
# Finding neighbors in VAE latent space
# Using pre-existing region information from stratified split
# Region distribution before augmentation:
#   Region 1 (1.50 to 2.22): 3 samples → Target: 15
#   Region 2 (2.22 to 3.72): 3 samples → Target: 15
#   Region 3 (3.72 to 5.47): 3 samples → Target: 15
#   Region 4 (5.47 to 8.48): 2 samples → Target: 15
#   Region 5 (8.48 to 10.54): 3 samples → Target: 15
#   Region 6 (10.54 to 11.70): 3 samples → Target: 15
#   Region 7 (11.70 to 20.63): 2 samples → Target: 15
#   Region 8 (20.63 to 32.08): 3 samples → Target: 15
#   Region 9 (32.08 to 54.11): 3 samples → Target: 15
#   Region 10 (54.11 to 103.86): 3 samples → Target: 15
# Initial KDE quality: bandwidth=10.5755, log-likelihood=-4.2583
# Increased bandwidth: 15.8633, log-likelihood: -4.4316
# Decreased bandwidth: 7.9316, log-likelihood: -4.1430
# Selected bandwidth: 7.9316, log-likelihood: -4.1430
# Initial KDE quality: bandwidth=10.5755, log-likelihood=-4.2583
# Increased bandwidth: 15.8633, log-likelihood: -4.4316
# Decreased bandwidth: 7.9316, log-likelihood: -4.1430
# Selected bandwidth: 7.9316, log-likelihood: -4.1430
# Initial KDE quality: bandwidth=10.5755, log-likelihood=-4.2583
# Increased bandwidth: 15.8633, log-likelihood: -4.4316
# Decreased bandwidth: 7.9316, log-likelihood: -4.1430
# Selected bandwidth: 7.9316, log-likelihood: -4.1430
# Generating synthetic samples with KDE-based balanced upsampling...
# Region 1: Generating 12 synthetic samples
# Region 2: Generating 12 synthetic samples
# Region 3: Generating 12 synthetic samples
# Region 4: Generating 13 synthetic samples
# Region 5: Generating 12 synthetic samples
# Region 6: Generating 12 synthetic samples
# Region 7: Generating 13 synthetic samples
# Region 8: Generating 12 synthetic samples
# Region 9: Generating 12 synthetic samples
# Region 10: Generating 12 synthetic samples
#
# Region distribution after augmentation:
#   Region 1 (1.50 to 2.22): 3 + 14 = 17 samples
#   Region 2 (2.22 to 3.72): 3 + 8 = 11 samples
#   Region 3 (3.72 to 5.47): 3 + 6 = 9 samples
#   Region 4 (5.47 to 8.48): 2 + 21 = 23 samples
#   Region 5 (8.48 to 10.54): 3 + 14 = 17 samples
#   Region 6 (10.54 to 11.70): 3 + 1 = 4 samples
#   Region 7 (11.70 to 20.63): 2 + 21 = 23 samples
#   Region 8 (20.63 to 32.08): 3 + 14 = 17 samples
#   Region 9 (32.08 to 54.11): 3 + 18 = 21 samples
#   Region 10 (54.11 to 103.86): 3 + 5 = 8 samples
# Generated 122 synthetic samples in 0.09 seconds
# x synthetic = [[8.7818976e+02 9.8576860e+00 6.4110851e-01 ... 6.1049545e-01
#   7.9548138e-01 8.2198244e-01]
#  [7.8978394e+02 8.5042486e+00 5.5042565e-01 ... 5.8170944e-01
#   7.7215052e-01 7.9194045e-01]
#  [7.5027234e+02 7.9227057e+00 5.1281005e-01 ... 5.6630540e-01
#   7.5525409e-01 7.8292769e-01]
#  ...
#  [5.4433667e+02 5.0632443e+00 2.2432232e-01 ... 3.4444261e-01
#   4.1396061e-01 3.6567268e-01]
#  [5.3586810e+02 4.9819441e+00 2.1720885e-01 ... 3.5345823e-01
#   3.9777175e-01 3.6275849e-01]
#  [5.3595911e+02 5.0016727e+00 2.2123513e-01 ... 3.4630436e-01
#   3.8813025e-01 3.4910876e-01]]
# 2025-09-04 18:01:16,520 - INFO - Best parameters: {'bootstrap': False, 'max_depth': 14, 'max_features': 'log2', 'min_samples_leaf': 3, 'min_samples_split': 9, 'n_estimators': 122, 'oob_score': False}

# %%
reg_train
# Out:
# {'metrics': {'train_mae': np.float64(10.787708146229491),
#   'train_mse': np.float64(176.567128500069),
#   'train_adj_r2': 0,
#   'train_r2': 0.7913984806556629,
#   'test_mae': np.float64(12.44609613402858),
#   'test_mse': np.float64(210.2557867128544),
#   'test_adj_r2': 0,
#   'test_r2': -0.0018848062643461727},
#  'model_name': 'randomforest',
#  'model': RandomForestRegressor(bootstrap=False, max_depth=3, max_features='log2',
#                        min_samples_leaf=4, min_samples_split=6, n_estimators=39),
#  'hyperparameters': [{'Hyperparameter Name': 'bootstrap',
#    'Hyperparameter Value': False},
#   {'Hyperparameter Name': 'ccp_alpha', 'Hyperparameter Value': 0.0},
#   {'Hyperparameter Name': 'criterion',
#    'Hyperparameter Value': 'squared_error'},
#   {'Hyperparameter Name': 'max_depth', 'Hyperparameter Value': 3},
#   {'Hyperparameter Name': 'max_features', 'Hyperparameter Value': 'log2'},
#   {'Hyperparameter Name': 'max_leaf_nodes', 'Hyperparameter Value': None},
#   {'Hyperparameter Name': 'max_samples', 'Hyperparameter Value': None},
#   {'Hyperparameter Name': 'min_impurity_decrease',
#    'Hyperparameter Value': 0.0},
#   {'Hyperparameter Name': 'min_samples_leaf', 'Hyperparameter Value': 4},
#   {'Hyperparameter Name': 'min_samples_split', 'Hyperparameter Value': 6},
#   {'Hyperparameter Name': 'min_weight_fraction_leaf',
#    'Hyperparameter Value': 0.0},
#   {'Hyperparameter Name': 'monotonic_cst', 'Hyperparameter Value': None},
#   {'Hyperparameter Name': 'n_estimators', 'Hyperparameter Value': 39},
#   {'Hyperparameter Name': 'oob_score', 'Hyperparameter Value': False}],
#  'scaler': MinMaxScaler(),
#  'features': ['Mass',
#   'HDonors',
#   'LogP',
#   'Asphericity',
#   'Rg',
#   'NumHeteroatoms',
#   'HOMOm1(eV)',
#   'LUMO(eV)',
#   'PrimeState',
#   'SurfaceCharge',
#   'T2',
#   'T4',
#   'T6',
#   'T7',
#   'T11',
#   'T14',
#   'T17',
#   'T18',
#   'T20',
#   'S1',
#   'S2',
#   'S3',
#   'S4',
#   'S5',
#   'S6',
#   'S7',
#   'S11',
#   'S14',
#   'S18',
#   'O1',
#   'O3',
#   'O5',
#   'O7',
#   'O9',
#   'O13',
#   'O14',
#   'O18',
#   'O20',
#   'TDOS1.5',
#   'TDOS1.6',
#   'TDOS1.9',
#   'TDOS2.5',
#   'TDOS3.0',
#   'TDOS3.2',
#   'TDOS3.3',
#   'TDOS3.4',
#   'TDOS3.6',
#   'TDOS3.7',
#   'TDOS3.8',
#   'TDOS3.9',
#   'TDOS4.1',
#   'TDOS4.4',
#   'TDOS4.5',
#   'TDOS4.6',
#   'SDOS2.5',
#   'SDOS2.6',
#   'SDOS2.7',
#   'SDOS2.8',
#   'SDOS2.9',
#   'SDOS3.0',
#   'SDOS3.2',
#   'SDOS3.5',
#   'SDOS3.8',
#   'SDOS3.9',
#   'SDOS4.1',
#   'SDOS4.2',
#   'SDOS4.3',
#   'SDOS4.5',
#   'SDOS4.6',
#   'SDOS4.7',
#   'SDOS5.0',
#   'SDOS5.1',
#   'SDOS5.2',
#   'SDOS5.3'],
#  'goal_metric_per_folds': {'train': [np.float64(176.567128500069),
#    np.float64(138.14890644125566),
#    np.float64(75.37493797828681),
#    np.float64(87.01979961909635),
#    np.float64(43.36588754988647)],
#   'test': [np.float64(210.2557867128544),
#    np.float64(441.8163790673113),
#    np.float64(488.9641592873093),
#    np.float64(452.35873610974534),
#    np.float64(803.859271762642)]},
#  'true_prediction_point': {'train': [{'true': 103.86,
#     'predicted': 80.60092760603875},
#    {'true': 101.13, 'predicted': 81.02937317104266},
#    {'true': 71.88, 'predicted': 39.877764779342726},
#    {'true': 68.37, 'predicted': 42.196125556007786},
#    {'true': 44.96, 'predicted': 29.09984980266822},
#    {'true': 38.74, 'predicted': 19.78670949770896},
#    {'true': 24.91, 'predicted': 21.865232087118027},
#    {'true': 23.09, 'predicted': 17.756701092195247},
#    {'true': 19.48, 'predicted': 16.743797981825434},
#    {'true': 15.0, 'predicted': 19.086688282843017},
#    {'true': 10.88, 'predicted': 12.972327201587351},
#    {'true': 10.8, 'predicted': 16.625269487856652},
#    {'true': 10.49, 'predicted': 14.399049405962074},
#    {'true': 10.48, 'predicted': 12.199569344677787},
#    {'true': 9.3, 'predicted': 13.182993793219872},
#    {'true': 8.87, 'predicted': 14.918759978235906},
#    {'true': 8.64, 'predicted': 14.662439018248241},
#    {'true': 7.86, 'predicted': 18.238518522258524},
#    {'true': 6.67, 'predicted': 18.635814192981076},
#    {'true': 5.34, 'predicted': 14.243486858175533},
#    {'true': 5.0, 'predicted': 17.399373890612427},
#    {'true': 3.0, 'predicted': 14.66738988601765},
#    {'true': 2.42, 'predicted': 11.938329279731727},
#    {'true': 2.36, 'predicted': 20.753638130002653},
#    {'true': 1.9, 'predicted': 9.709430502386166},
#    {'true': 1.5, 'predicted': 12.091718429844345},
#    {'true': 1.5, 'predicted': 10.089805317503075}],
#   'test': [{'true': 48.0, 'predicted': 63.846123850088134},
#    {'true': 32.17, 'predicted': 17.20303446877774},
#    {'true': 31.94, 'predicted': 33.09419395490605},
#    {'true': 10.6, 'predicted': 17.726127648714943},
#    {'true': 9.15, 'predicted': 16.808510321425224},
#    {'true': 4.8, 'predicted': 19.026543054794736},
#    {'true': 20.76, 'predicted': 46.904208577048706}]}}

# %%
reg_train
# Out:
# {'metrics': {'train_mae': np.float64(10.787708146229491),
#   'train_mse': np.float64(176.567128500069),
#   'train_adj_r2': 0,
#   'train_r2': 0.7913984806556629,
#   'test_mae': np.float64(12.44609613402858),
#   'test_mse': np.float64(210.2557867128544),
#   'test_adj_r2': 0,
#   'test_r2': -0.0018848062643461727},
#  'model_name': 'randomforest',
#  'model': RandomForestRegressor(bootstrap=False, max_depth=3, max_features='log2',
#                        min_samples_leaf=4, min_samples_split=6, n_estimators=39),
#  'hyperparameters': [{'Hyperparameter Name': 'bootstrap',
#    'Hyperparameter Value': False},
#   {'Hyperparameter Name': 'ccp_alpha', 'Hyperparameter Value': 0.0},
#   {'Hyperparameter Name': 'criterion',
#    'Hyperparameter Value': 'squared_error'},
#   {'Hyperparameter Name': 'max_depth', 'Hyperparameter Value': 3},
#   {'Hyperparameter Name': 'max_features', 'Hyperparameter Value': 'log2'},
#   {'Hyperparameter Name': 'max_leaf_nodes', 'Hyperparameter Value': None},
#   {'Hyperparameter Name': 'max_samples', 'Hyperparameter Value': None},
#   {'Hyperparameter Name': 'min_impurity_decrease',
#    'Hyperparameter Value': 0.0},
#   {'Hyperparameter Name': 'min_samples_leaf', 'Hyperparameter Value': 4},
#   {'Hyperparameter Name': 'min_samples_split', 'Hyperparameter Value': 6},
#   {'Hyperparameter Name': 'min_weight_fraction_leaf',
#    'Hyperparameter Value': 0.0},
#   {'Hyperparameter Name': 'monotonic_cst', 'Hyperparameter Value': None},
#   {'Hyperparameter Name': 'n_estimators', 'Hyperparameter Value': 39},
#   {'Hyperparameter Name': 'oob_score', 'Hyperparameter Value': False}],
#  'scaler': MinMaxScaler(),
#  'features': ['Mass',
#   'HDonors',
#   'LogP',
#   'Asphericity',
#   'Rg',
#   'NumHeteroatoms',
#   'HOMOm1(eV)',
#   'LUMO(eV)',
#   'PrimeState',
#   'SurfaceCharge',
#   'T2',
#   'T4',
#   'T6',
#   'T7',
#   'T11',
#   'T14',
#   'T17',
#   'T18',
#   'T20',
#   'S1',
#   'S2',
#   'S3',
#   'S4',
#   'S5',
#   'S6',
#   'S7',
#   'S11',
#   'S14',
#   'S18',
#   'O1',
#   'O3',
#   'O5',
#   'O7',
#   'O9',
#   'O13',
#   'O14',
#   'O18',
#   'O20',
#   'TDOS1.5',
#   'TDOS1.6',
#   'TDOS1.9',
#   'TDOS2.5',
#   'TDOS3.0',
#   'TDOS3.2',
#   'TDOS3.3',
#   'TDOS3.4',
#   'TDOS3.6',
#   'TDOS3.7',
#   'TDOS3.8',
#   'TDOS3.9',
#   'TDOS4.1',
#   'TDOS4.4',
#   'TDOS4.5',
#   'TDOS4.6',
#   'SDOS2.5',
#   'SDOS2.6',
#   'SDOS2.7',
#   'SDOS2.8',
#   'SDOS2.9',
#   'SDOS3.0',
#   'SDOS3.2',
#   'SDOS3.5',
#   'SDOS3.8',
#   'SDOS3.9',
#   'SDOS4.1',
#   'SDOS4.2',
#   'SDOS4.3',
#   'SDOS4.5',
#   'SDOS4.6',
#   'SDOS4.7',
#   'SDOS5.0',
#   'SDOS5.1',
#   'SDOS5.2',
#   'SDOS5.3'],
#  'goal_metric_per_folds': {'train': [np.float64(176.567128500069),
#    np.float64(138.14890644125566),
#    np.float64(75.37493797828681),
#    np.float64(87.01979961909635),
#    np.float64(43.36588754988647)],
#   'test': [np.float64(210.2557867128544),
#    np.float64(441.8163790673113),
#    np.float64(488.9641592873093),
#    np.float64(452.35873610974534),
#    np.float64(803.859271762642)]},
#  'true_prediction_point': {'train': [{'true': 103.86,
#     'predicted': 80.60092760603875},
#    {'true': 101.13, 'predicted': 81.02937317104266},
#    {'true': 71.88, 'predicted': 39.877764779342726},
#    {'true': 68.37, 'predicted': 42.196125556007786},
#    {'true': 44.96, 'predicted': 29.09984980266822},
#    {'true': 38.74, 'predicted': 19.78670949770896},
#    {'true': 24.91, 'predicted': 21.865232087118027},
#    {'true': 23.09, 'predicted': 17.756701092195247},
#    {'true': 19.48, 'predicted': 16.743797981825434},
#    {'true': 15.0, 'predicted': 19.086688282843017},
#    {'true': 10.88, 'predicted': 12.972327201587351},
#    {'true': 10.8, 'predicted': 16.625269487856652},
#    {'true': 10.49, 'predicted': 14.399049405962074},
#    {'true': 10.48, 'predicted': 12.199569344677787},
#    {'true': 9.3, 'predicted': 13.182993793219872},
#    {'true': 8.87, 'predicted': 14.918759978235906},
#    {'true': 8.64, 'predicted': 14.662439018248241},
#    {'true': 7.86, 'predicted': 18.238518522258524},
#    {'true': 6.67, 'predicted': 18.635814192981076},
#    {'true': 5.34, 'predicted': 14.243486858175533},
#    {'true': 5.0, 'predicted': 17.399373890612427},
#    {'true': 3.0, 'predicted': 14.66738988601765},
#    {'true': 2.42, 'predicted': 11.938329279731727},
#    {'true': 2.36, 'predicted': 20.753638130002653},
#    {'true': 1.9, 'predicted': 9.709430502386166},
#    {'true': 1.5, 'predicted': 12.091718429844345},
#    {'true': 1.5, 'predicted': 10.089805317503075}],
#   'test': [{'true': 48.0, 'predicted': 63.846123850088134},
#    {'true': 32.17, 'predicted': 17.20303446877774},
#    {'true': 31.94, 'predicted': 33.09419395490605},
#    {'true': 10.6, 'predicted': 17.726127648714943},
#    {'true': 9.15, 'predicted': 16.808510321425224},
#    {'true': 4.8, 'predicted': 19.026543054794736},
#    {'true': 20.76, 'predicted': 46.904208577048706}]}}

# %%
target_provided = True
df_infer = df_infer[reg_train["features"] + [target]] if target_provided else df_infer[reg_train["features"]]

# %%
#infer
reg_infer = regression.RegressionBuilder(
        None,
        df_infer,
        target,
        hyperparameters_tune=True,
        feature_selection_autoselect=True,
        model_choice=["randomforest"],#ast.literal_eval(job_params["models"]),
        goal_metric="r2",
        data_augmentation=False,#True,#job_params["data_augmentation"].lower() == "true",
        feature_selection_num=0,
        saved_model=reg_train["model"],
        saved_scaler=reg_train["scaler"],
        data_augmentation_method=None,
        data_augmentation_sectioning=None,
        data_augmentation_region_num=None,
        data_augmentation_min_samples_per_region=None,
        k=5,
        target_provided=target_provided
    ).run_regression()
# Out:
# Index(['Mass', 'HDonors', 'LogP', 'Asphericity', 'Rg', 'NumHeteroatoms',
#        'HOMOm1(eV)', 'LUMO(eV)', 'PrimeState', 'SurfaceCharge', 'T2', 'T4',
#        'T6', 'T7', 'T11', 'T14', 'T17', 'T18', 'T20', 'S1', 'S2', 'S3', 'S4',
#        'S5', 'S6', 'S7', 'S11', 'S14', 'S18', 'O1', 'O3', 'O5', 'O7', 'O9',
#        'O13', 'O14', 'O18', 'O20', 'TDOS1.5', 'TDOS1.6', 'TDOS1.9', 'TDOS2.5',
#        'TDOS3.0', 'TDOS3.2', 'TDOS3.3', 'TDOS3.4', 'TDOS3.6', 'TDOS3.7',
#        'TDOS3.8', 'TDOS3.9', 'TDOS4.1', 'TDOS4.4', 'TDOS4.5', 'TDOS4.6',
#        'SDOS2.5', 'SDOS2.6', 'SDOS2.7', 'SDOS2.8', 'SDOS2.9', 'SDOS3.0',
#        'SDOS3.2', 'SDOS3.5', 'SDOS3.8', 'SDOS3.9', 'SDOS4.1', 'SDOS4.2',
#        'SDOS4.3', 'SDOS4.5', 'SDOS4.6', 'SDOS4.7', 'SDOS5.0', 'SDOS5.1',
#        'SDOS5.2', 'SDOS5.3'],
#       dtype='object')

# %%
reg_infer
# Out:
# {'predictions': [59.64101201740024,
#   14.726234074416384,
#   12.596094526344283,
#   13.099176707400959,
#   23.90917074045246,
#   41.44260737729555,
#   29.33374912770649,
#   55.06883853645706],
#  'test_metrics': {'test_mae': np.float64(23.64752523389395),
#   'test_mse': np.float64(812.783886136455),
#   'test_adj_r2': nan,
#   'test_r2': -0.2189521771924401,
#   'test_true_predicted': [{'true': 78.3, 'predicted': 59.64101201740024},
#    {'true': 51.7, 'predicted': 14.726234074416384},
#    {'true': 15.64, 'predicted': 12.596094526344283},
#    {'true': 9.77, 'predicted': 13.099176707400959},
#    {'true': 9.7, 'predicted': 23.90917074045246},
#    {'true': 5.0, 'predicted': 41.44260737729555},
#    {'true': 3.5, 'predicted': 29.33374912770649},
#    {'true': 4.38, 'predicted': 55.06883853645706}]}}

# %%
reg_infer
# Out:
# {'predictions': [59.64101201740024,
#   14.726234074416384,
#   12.596094526344283,
#   13.099176707400959,
#   23.90917074045246,
#   41.44260737729555,
#   29.33374912770649,
#   55.06883853645706],
#  'test_metrics': {'test_mae': np.float64(23.64752523389395),
#   'test_mse': np.float64(812.783886136455),
#   'test_adj_r2': nan,
#   'test_r2': -0.2189521771924401,
#   'test_true_predicted': [{'true': 78.3, 'predicted': 59.64101201740024},
#    {'true': 51.7, 'predicted': 14.726234074416384},
#    {'true': 15.64, 'predicted': 12.596094526344283},
#    {'true': 9.77, 'predicted': 13.099176707400959},
#    {'true': 9.7, 'predicted': 23.90917074045246},
#    {'true': 5.0, 'predicted': 41.44260737729555},
#    {'true': 3.5, 'predicted': 29.33374912770649},
#    {'true': 4.38, 'predicted': 55.06883853645706}]}}

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import glob
import umap
from sklearn.preprocessing import StandardScaler

def analyze_augmentation_quality(base_path, target_col, n_components=2, n_neighbors=15, min_dist=0.1):
    """
    Analyze the quality of data augmentation by comparing distributions.
    
    Args:
        base_path: Path to either 'best_fold' or 'stratified_sampling' directory
        target_col: Name of the target column
        n_components: Number of UMAP dimensions (default: 2)
        n_neighbors: UMAP parameter controlling local vs global structure (default: 15)
        min_dist: UMAP parameter controlling compactness (default: 0.1)
    """
    # Find training file
    if 'best_fold' in base_path:
        train_files = glob.glob(os.path.join(base_path, 'iteration_*_train.csv'))
        if not train_files:
            print(f"No training files found in {base_path}")
            return
        print(f'train files - {train_files}')
        
        train_file = train_files[1] if 'organic' in train_files[0] else train_files[0]  # Use the first iteration file found
    else:
        train_file = os.path.join(base_path, 'train.csv')
        if not os.path.exists(train_file):
            print(f"No training file found at {train_file}")
            return
    
    print(f"Analyzing file: {train_file}")
    
    # Load data
    df = pd.read_csv(train_file)
    
    # Verify required columns exist
    if 'is_organic' not in df.columns:
        print("Error: 'is_organic' column not found in dataset")
        return
    if target_col not in df.columns:
        print(f"Error: Target column '{target_col}' not found in dataset")
        return
    
    # Split data into organic and synthetic
    organic_data = df[df['is_organic'] == True]
    synthetic_data = df[df['is_organic'] == False]
    
    print(f"Dataset contains {len(organic_data)} organic samples and {len(synthetic_data)} synthetic samples")
    
    # STEP 1: Create target distribution histograms
    plt.figure(figsize=(15, 5))
    
    # Histogram 1: Organic data only
    plt.subplot(1, 3, 1)
    plt.hist(organic_data[target_col], bins=30, color='blue', alpha=0.7)
    plt.title('Target Distribution: Organic Data')
    plt.xlabel(target_col)
    plt.ylabel('Frequency')
    
    # Histogram 2: Synthetic data only
    plt.subplot(1, 3, 2)
    plt.hist(synthetic_data[target_col], bins=30, color='red', alpha=0.7)
    plt.title('Target Distribution: Synthetic Data')
    plt.xlabel(target_col)
    plt.ylabel('Frequency')
    
    # Histogram 3: Combined data with different colors
    plt.subplot(1, 3, 3)
    plt.hist([organic_data[target_col], synthetic_data[target_col]], 
             bins=30, color=['blue', 'red'], alpha=0.7,
             label=['Organic', 'Synthetic'])
    plt.title('Target Distribution: Combined Data')
    plt.xlabel(target_col)
    plt.ylabel('Frequency')
    plt.legend()
    
    plt.tight_layout()
    plt.savefig('target_distribution_histograms.png')
    plt.show()
    
    # STEP 2: Create UMAP projections and scatter plots
    # Get all features excluding target and is_organic
    feature_cols = [col for col in df.columns if col != 'is_organic' 
                   and pd.api.types.is_numeric_dtype(df[col])]
    
    if len(feature_cols) < 2:
        print("Error: Not enough numerical features for UMAP")
        return
    
    # Standardize features before UMAP
    X = df[feature_cols]
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)
    
    # Apply UMAP
    reducer = umap.UMAP(n_components=n_components, 
                        n_neighbors=n_neighbors, 
                        min_dist=min_dist,
                        random_state=42)
    
    X_umap = reducer.fit_transform(X_scaled)
    
    # Add UMAP components to dataframe
    umap_cols = [f'UMAP{i+1}' for i in range(n_components)]
    df_umap = pd.DataFrame(X_umap, columns=umap_cols)
    df_umap['is_organic'] = df['is_organic'].values
    df_umap[target_col] = df[target_col].values
    
    # Split the UMAP results by is_organic
    organic_umap = df_umap[df_umap['is_organic'] == True]
    synthetic_umap = df_umap[df_umap['is_organic'] == False]
    
    # Create scatter plots with UMAP dimensions
    plt.figure(figsize=(15, 12))
    
    # 2D Scatter plot of UMAP dimensions
    plt.subplot(2, 2, 1)
    plt.scatter(organic_umap['UMAP1'], organic_umap['UMAP2'], 
                c='blue', alpha=0.5, label='Organic')
    plt.scatter(synthetic_umap['UMAP1'], synthetic_umap['UMAP2'], 
                c='red', alpha=0.5, label='Synthetic')
    plt.xlabel('UMAP1')
    plt.ylabel('UMAP2')
    plt.title('UMAP Projection: Organic vs Synthetic')
    plt.legend()
    
    # Scatter plot of UMAP1 vs target
    plt.subplot(2, 2, 2)
    plt.scatter(organic_umap['UMAP1'], organic_umap[target_col], 
                c='blue', alpha=0.5, label='Organic')
    plt.scatter(synthetic_umap['UMAP1'], synthetic_umap[target_col], 
                c='red', alpha=0.5, label='Synthetic')
    plt.xlabel('UMAP1')
    plt.ylabel(target_col)
    plt.title(f'UMAP1 vs {target_col}')
    plt.legend()
    
    # Scatter plot of UMAP2 vs target
    plt.subplot(2, 2, 3)
    plt.scatter(organic_umap['UMAP2'], organic_umap[target_col], 
                c='blue', alpha=0.5, label='Organic')
    plt.scatter(synthetic_umap['UMAP2'], synthetic_umap[target_col], 
                c='red', alpha=0.5, label='Synthetic')
    plt.xlabel('UMAP2')
    plt.ylabel(target_col)
    plt.title(f'UMAP2 vs {target_col}')
    plt.legend()
    
    # If we have 3 or more components, show UMAP3 vs target
    if n_components >= 3:
        plt.subplot(2, 2, 4)
        plt.scatter(organic_umap['UMAP3'], organic_umap[target_col], 
                    c='blue', alpha=0.5, label='Organic')
        plt.scatter(synthetic_umap['UMAP3'], synthetic_umap[target_col], 
                    c='red', alpha=0.5, label='Synthetic')
        plt.xlabel('UMAP3')
        plt.ylabel(target_col)
        plt.title(f'UMAP3 vs {target_col}')
        plt.legend()
    else:
        # If only 2 components, show density plot of target
        plt.subplot(2, 2, 4)
        sns.kdeplot(organic_umap[target_col], color='blue', label='Organic', fill=True, alpha=0.3)
        sns.kdeplot(synthetic_umap[target_col], color='red', label='Synthetic', fill=True, alpha=0.3)
        plt.xlabel(target_col)
        plt.ylabel('Density')
        plt.title(f'Distribution of {target_col}')
        plt.legend()
    
    plt.tight_layout()
    plt.savefig('umap_visualizations.png')
    plt.show()
    
    # Create 3D scatter plot if we have 3 or more components
    if n_components >= 3:
        fig = plt.figure(figsize=(10, 8))
        ax = fig.add_subplot(111, projection='3d')
        
        ax.scatter(organic_umap['UMAP1'], organic_umap['UMAP2'], organic_umap['UMAP3'], 
                   c='blue', alpha=0.5, label='Organic')
        ax.scatter(synthetic_umap['UMAP1'], synthetic_umap['UMAP2'], synthetic_umap['UMAP3'], 
                   c='red', alpha=0.5, label='Synthetic')
        
        ax.set_xlabel('UMAP1')
        ax.set_ylabel('UMAP2')
        ax.set_zlabel('UMAP3')
        ax.set_title('3D UMAP Projection')
        plt.legend()
        
        plt.tight_layout()
        plt.savefig('umap_3d.png')
        plt.show()
    
    # Additional visualization: Color by target value
    plt.figure(figsize=(15, 6))
    
    # UMAP plot colored by target (organic)
    plt.subplot(1, 2, 1)
    scatter1 = plt.scatter(organic_umap['UMAP1'], organic_umap['UMAP2'], 
                           c=organic_umap[target_col], cmap='viridis', alpha=0.7)
    plt.colorbar(scatter1, label=target_col)
    plt.xlabel('UMAP1')
    plt.ylabel('UMAP2')
    plt.title(f'Organic Data: UMAP colored by {target_col}')
    
    # UMAP plot colored by target (synthetic)
    plt.subplot(1, 2, 2)
    scatter2 = plt.scatter(synthetic_umap['UMAP1'], synthetic_umap['UMAP2'], 
                           c=synthetic_umap[target_col], cmap='viridis', alpha=0.7)
    plt.colorbar(scatter2, label=target_col)
    plt.xlabel('UMAP1')
    plt.ylabel('UMAP2')
    plt.title(f'Synthetic Data: UMAP colored by {target_col}')
    
    plt.tight_layout()
    plt.savefig('umap_target_colored.png')
    plt.show()

# %%
    base_path = "best_fold"  # or "stratified_sampling"
    target_column = target  # replace with your actual target column name
    
    # UMAP parameters
    n_components = 2  # Set to 2 for 2D plots only, 3 for 3D visualization
    n_neighbors = 15  # Lower for local structure, higher for global
    min_dist = 0.1    # Lower for tighter clusters
    
    analyze_augmentation_quality(base_path, target_column, n_components, n_neighbors, min_dist)
# Out:
# train files - ['best_fold/iteration_1_organic_train.csv', 'best_fold/iteration_1_train.csv']
# Analyzing file: best_fold/iteration_1_organic_train.csv
# Error: 'is_organic' column not found in dataset
